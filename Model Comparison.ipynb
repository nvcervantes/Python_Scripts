# %%
import pandas as pd
tr_data = pd.read_csv('categorization_data.csv', encoding="latin1")

# %%
tr_data
# Out:
#              Number                                              Title  \
# 0     INC0059672965  Missing ELK Records for Gateway MSST_CRDS_NAM_...
# 1     INC0058335285                          Issue with ELK Alert Sync
# 2     INC0057358766                          RE: Inconsistent ELK data
# 3     INC0057388669  Prod Gateway TTS_ELK_NAM_PROD not accessible |...
# 4     INC0057046947  Authentication failure with new ITRS gateway |...
# 5     INC0055908871            GCE : Getting  ELK alerts for Zero rows
# 6     INC0055588345                          GCE : Getting  ELK alerts
# 7     INC0055563666  ELK not collecting alerts from TTS_FLEXCUBE_NA...
# 8     INC0059603741                       Sync ITRS gateways for Trade
# 9     INC0059292483                      Sync ITRS gateways for Trade
# 10    INC0058944579  PROD Gateway Entitlement SYNC Issues | Multipl...
# 11    INC0059263252                 Sync ITRS gateways for channels |
# 12    INC0059171980  Entitlement sync issue | TTS_GPCD_GBS_STARS_IV...
# 13    INC0058683413           entitlement issue for MSST_CRDS_NAM_PROD
# 14    INC0058092741    Entitlement sync for CPB_EMEA_APAC_PROD gateway
# 15    INC0057049141              ITRS : Sync Issue : TTS_LMS1_NAM_PROD
# 16    INC0057265001  Change the port to 7136 / 7137 so that NetProb...
# 17    INC0057041545  [20181012: PENDING ENGG] Not  able to create S...
# 18    INC0057049313  ITRS : Sync Issue : TTS_LMS1_NAM_PROD SN# INC0...
# 19    INC0055910058           users not getting added during the synch
# 20    INC0055527766  ITRS monitoring - {ENV - PROD or COB} environm...
# 21    INC0059857722  rdcgtsncsaa01p : ITM6_K20:alert on process net...
# 22    INC0059882981  lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 23    INC0059943875  lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 24    INC0059945178  lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 25    INC0059828610  lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 26    INC0059794089  lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 27    INC0059920369  hdcicgitvld01c : Filesystem /var free space is...
# 28    INC0059729274  lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 29    INC0059857245  lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# ...             ...                                                ...
# 1268  INC0056097051  GHC webdashboard not working | TTS | Dashboard...
# 1269  INC0055909605                   Unable to load ITRS from web url
# 1270  INC0056052775                        Uploading XMC ETL Dashboard
# 1271  INC0056040160  ITRS Web Dashboard - Few gateway's not working...
# 1272  INC0056038884  ITRS Web Dashboard - Few gateway's not working...
# 1273  INC0055982523  Web Dashboard Hosting | ISG_PRODUCT_NAM_PROD |...
# 1274  INC0055826223  Stale web dashboard not displaying correct inf...
# 1275  INC0055941821                            Update XMC UI Dashboard
# 1276  INC0055906603                           Upload XMC QV Dashboards
# 1277  INC0055757860  http://itrsswcob2:8093/ | Web dashboard URL no...
# 1278  INC0055850592                                   WEB Dashboard BO
# 1279  INC0055657315  Dashboard doesn't load, please check attached ...
# 1280  INC0055787326                           Upload XMC UI Dashboards
# 1281  INC0055633270            FX Velocity: SOW ITRS Dashboard - Stale
# 1282  INC0055469800          [RCA ] Web Dashboard Unavailability Issue
# 1283  INC0055709555                          CS - Web dashboard update
# 1284  INC0055485710  Web dashboard issue - DDE | TTS | Web Dashboar...
# 1285  INC0055559171             ALL - MAINT - ITRS Web dashboard issue
# 1286  INC0059945718              Few Data views not visible on montage
# 1287  INC0059736383  COB Web montage url -None of the credentials a...
# 1288  INC0059721068                       Web montage url -not working
# 1289  INC0058887752            **URGENT** Web montage url -not working
# 1290  INC0058037386                       Web montage url -not working
# 1291  INC0056707987                                        web montage
# 1292  INC0056487009  Web montage url -not working | TTS_CRM_NAM_PRO...
# 1293  INC0056198886  http://eqitrspsnj1.nam.nsroot.net:8181/-  Webm...
# 1294  INC0056046473                                 web Montage Access
# 1295  INC0056691767  [20181112: ZD210049, ONGOING] URGENT - Busines...
# 1296  INC0057487375                         Webslinger Setup Reference
# 1297  INC0056735990   Webslinger and action script for Solace gateways
#
#                                             Description  \
# 0     Could  you please help to check and advise why...
# 1     Hi Support Team, \n\nThere seems to be an issu...
# 2     Hi Carlo,\n\nWe executed the same query in ELK...
# 3     ITRS PROD gateway(TTS_ELK_NAM_PROD) is not acc...
# 4     The new ITRS  gateway created is failing with ...
# 5     This is continuation of INC0055588345 - Please...
# 6     Hi Jignisha/fazil,\nAs discussed on call/IM, w...
# 7     ELK not collecting alerts from TTS_FLEXCUBE_NA...
# 8     Hi ITRS Team,\n\nNew resources were added into...
# 9     Hi ITRS Team,\n\nNew resources were added into...
# 10    Same issue is happening in 2 PROD gateways\n\n...
# 11    Hi ITRS Team,\n\nNew resources were added into...
# 12    We added some users to the L1 group yesterday,...
# 13    Can you please help check the entitlement issu...
# 14    Hi Team,\nCould you please help to refresh the...
# 15    Hi ITRS team,\n\nGateway : TTS_LMS1_NAM_PROD\n...
# 16    Please change the port to 7136 / 7137 so that ...
# 17    Gateway: MSST_REGIONAL2_LATAM_PROD\n\nI´m Appl...
# 18    Hi ITRS team,\n\nFor Gateway : TTS_LMS1_NAM_PR...
# 19    I have ran a synch yesterday and today on TTS_...
# 20    I understand that ITRS support team do not sup...
# 21    rdcgtsncsaa01p : Critical : ITM6K20 : ITM6_K20...
# 22    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 23    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 24    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 25    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 26    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 27    Full title: hdcicgitvld01c : Filesystem /var f...
# 28    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 29    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# ...                                                 ...
# 1268  ITRS platform team,\n\nThe global health check...
# 1269  Hi ITRS team, \n\nI would like to acquire acce...
# 1270  Hi Team,\n   Raising the Incident  to update W...
# 1271  We have multiple gateway's in our ITRS web das...
# 1272  We have multiple gateway's in our ITRS web das...
# 1273      ITRS Web Dashboard Upload | ISG | Web Dash...
# 1274  Hi team, \n\nDashboard http://lswitrswsap1c:93...
# 1275  Hi Team,\nRaising this Incident to update Web ...
# 1276  ITRS Web Dashboard Upload | ISG | Web Dashboar...
# 1277  Web dashboard URL is not responding to request...
# 1278  Hi Team,\n\nPlease load the attached Dashboard...
# 1279  dashboard doesn't load, please check attached ...
# 1280  Hi Team,\nRaising this Incident to upload Web ...
# 1281  ITRS Support - Our FX Velocity SOW Dashboard i...
# 1282  Please consider problem where ALL dashboards a...
# 1283  Please update CS web dashboard with the attach...
# 1284  Hi Team,\n\nWe are having an issue with below ...
# 1285  ITRS web dashboard not linking\nhttp://lswitrs...
# 1286  Trying to migrate data views on montage with c...
# 1287  I tried with two:\n\nttscrmdev\ncrmuat\n\nThan...
# 1288  Hi ITRS Team,\n\nBelow web montage URL is not ...
# 1289  Hi ITRS Team,\n\nBelow web montage URL is not ...
# 1290  Hi ITRS Team,\n\nBelow web montage URL is not ...
# 1291  Yes we'd like it for a few of our gateway. \n\...
# 1292  Hi ITRS Team,\n\nBelow web montage URL is not ...
# 1293  http://eqitrspsnj1.nam.nsroot.net:8181/-  Webm...
# 1294  Hi Team,\n\nOur L0 can access below web montag...
# 1295  We have a critical trading dashboard for our t...
# 1296  Hi Team,\nWe are trying to build the webslinge...
# 1297  Please help us setup Webslinger and Gateway 2 ...
#
#                           CATEGORY
# 0                    Bespoke - ELK
# 1                    Bespoke - ELK
# 2                    Bespoke - ELK
# 3                    Bespoke - ELK
# 4                    Bespoke - ELK
# 5                    Bespoke - ELK
# 6                    Bespoke - ELK
# 7                    Bespoke - ELK
# 8           Bespoke - Gateway Sync
# 9           Bespoke - Gateway Sync
# 10          Bespoke - Gateway Sync
# 11          Bespoke - Gateway Sync
# 12          Bespoke - Gateway Sync
# 13          Bespoke - Gateway Sync
# 14          Bespoke - Gateway Sync
# 15          Bespoke - Gateway Sync
# 16          Bespoke - Gateway Sync
# 17          Bespoke - Gateway Sync
# 18          Bespoke - Gateway Sync
# 19          Bespoke - Gateway Sync
# 20          Bespoke - Gateway Sync
# 21          Bespoke - Health Check
# 22          Bespoke - Health Check
# 23          Bespoke - Health Check
# 24          Bespoke - Health Check
# 25          Bespoke - Health Check
# 26          Bespoke - Health Check
# 27          Bespoke - Health Check
# 28          Bespoke - Health Check
# 29          Bespoke - Health Check
# ...                            ...
# 1268  Visualisation - WebDashboard
# 1269  Visualisation - WebDashboard
# 1270  Visualisation - WebDashboard
# 1271  Visualisation - WebDashboard
# 1272  Visualisation - WebDashboard
# 1273  Visualisation - WebDashboard
# 1274  Visualisation - WebDashboard
# 1275  Visualisation - WebDashboard
# 1276  Visualisation - WebDashboard
# 1277  Visualisation - WebDashboard
# 1278  Visualisation - WebDashboard
# 1279  Visualisation - WebDashboard
# 1280  Visualisation - WebDashboard
# 1281  Visualisation - WebDashboard
# 1282  Visualisation - WebDashboard
# 1283  Visualisation - WebDashboard
# 1284  Visualisation - WebDashboard
# 1285  Visualisation - WebDashboard
# 1286    Visualisation - WebMontage
# 1287    Visualisation - WebMontage
# 1288    Visualisation - WebMontage
# 1289    Visualisation - WebMontage
# 1290    Visualisation - WebMontage
# 1291    Visualisation - WebMontage
# 1292    Visualisation - WebMontage
# 1293    Visualisation - WebMontage
# 1294    Visualisation - WebMontage
# 1295    Visualisation - WebSlinger
# 1296    Visualisation - WebSlinger
# 1297    Visualisation - WebSlinger
#
# [1298 rows x 4 columns]

# %%
tr_data['title_and_description'] = tr_data[['Title', 'Description']].apply(tuple, axis=1)

# %%
tr_data.to_csv('categorizationdata_withtad.csv')

# %%
tr_data = pd.read_csv('categorizationdata_withtad.csv')

# %%
tr_data
# Out:
#       Unnamed: 0         Number  \
# 0              0  INC0059672965
# 1              1  INC0058335285
# 2              2  INC0057358766
# 3              3  INC0057388669
# 4              4  INC0057046947
# 5              5  INC0055908871
# 6              6  INC0055588345
# 7              7  INC0055563666
# 8              8  INC0059603741
# 9              9  INC0059292483
# 10            10  INC0058944579
# 11            11  INC0059263252
# 12            12  INC0059171980
# 13            13  INC0058683413
# 14            14  INC0058092741
# 15            15  INC0057049141
# 16            16  INC0057265001
# 17            17  INC0057041545
# 18            18  INC0057049313
# 19            19  INC0055910058
# 20            20  INC0055527766
# 21            21  INC0059857722
# 22            22  INC0059882981
# 23            23  INC0059943875
# 24            24  INC0059945178
# 25            25  INC0059828610
# 26            26  INC0059794089
# 27            27  INC0059920369
# 28            28  INC0059729274
# 29            29  INC0059857245
# ...          ...            ...
# 1268        1268  INC0056097051
# 1269        1269  INC0055909605
# 1270        1270  INC0056052775
# 1271        1271  INC0056040160
# 1272        1272  INC0056038884
# 1273        1273  INC0055982523
# 1274        1274  INC0055826223
# 1275        1275  INC0055941821
# 1276        1276  INC0055906603
# 1277        1277  INC0055757860
# 1278        1278  INC0055850592
# 1279        1279  INC0055657315
# 1280        1280  INC0055787326
# 1281        1281  INC0055633270
# 1282        1282  INC0055469800
# 1283        1283  INC0055709555
# 1284        1284  INC0055485710
# 1285        1285  INC0055559171
# 1286        1286  INC0059945718
# 1287        1287  INC0059736383
# 1288        1288  INC0059721068
# 1289        1289  INC0058887752
# 1290        1290  INC0058037386
# 1291        1291  INC0056707987
# 1292        1292  INC0056487009
# 1293        1293  INC0056198886
# 1294        1294  INC0056046473
# 1295        1295  INC0056691767
# 1296        1296  INC0057487375
# 1297        1297  INC0056735990
#
#                                                   Title  \
# 0     Missing ELK Records for Gateway MSST_CRDS_NAM_...
# 1                             Issue with ELK Alert Sync
# 2                             RE: Inconsistent ELK data
# 3     Prod Gateway TTS_ELK_NAM_PROD not accessible |...
# 4     Authentication failure with new ITRS gateway |...
# 5               GCE : Getting  ELK alerts for Zero rows
# 6                             GCE : Getting  ELK alerts
# 7     ELK not collecting alerts from TTS_FLEXCUBE_NA...
# 8                          Sync ITRS gateways for Trade
# 9                         Sync ITRS gateways for Trade
# 10    PROD Gateway Entitlement SYNC Issues | Multipl...
# 11                   Sync ITRS gateways for channels |
# 12    Entitlement sync issue | TTS_GPCD_GBS_STARS_IV...
# 13             entitlement issue for MSST_CRDS_NAM_PROD
# 14      Entitlement sync for CPB_EMEA_APAC_PROD gateway
# 15                ITRS : Sync Issue : TTS_LMS1_NAM_PROD
# 16    Change the port to 7136 / 7137 so that NetProb...
# 17    [20181012: PENDING ENGG] Not  able to create S...
# 18    ITRS : Sync Issue : TTS_LMS1_NAM_PROD SN# INC0...
# 19             users not getting added during the synch
# 20    ITRS monitoring - {ENV - PROD or COB} environm...
# 21    rdcgtsncsaa01p : ITM6_K20:alert on process net...
# 22    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 23    lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 24    lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 25    lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 26    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 27    hdcicgitvld01c : Filesystem /var free space is...
# 28    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 29    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# ...                                                 ...
# 1268  GHC webdashboard not working | TTS | Dashboard...
# 1269                   Unable to load ITRS from web url
# 1270                        Uploading XMC ETL Dashboard
# 1271  ITRS Web Dashboard - Few gateway's not working...
# 1272  ITRS Web Dashboard - Few gateway's not working...
# 1273  Web Dashboard Hosting | ISG_PRODUCT_NAM_PROD |...
# 1274  Stale web dashboard not displaying correct inf...
# 1275                            Update XMC UI Dashboard
# 1276                           Upload XMC QV Dashboards
# 1277  http://itrsswcob2:8093/ | Web dashboard URL no...
# 1278                                   WEB Dashboard BO
# 1279  Dashboard doesn't load, please check attached ...
# 1280                           Upload XMC UI Dashboards
# 1281            FX Velocity: SOW ITRS Dashboard - Stale
# 1282          [RCA ] Web Dashboard Unavailability Issue
# 1283                          CS - Web dashboard update
# 1284  Web dashboard issue - DDE | TTS | Web Dashboar...
# 1285             ALL - MAINT - ITRS Web dashboard issue
# 1286              Few Data views not visible on montage
# 1287  COB Web montage url -None of the credentials a...
# 1288                       Web montage url -not working
# 1289            **URGENT** Web montage url -not working
# 1290                       Web montage url -not working
# 1291                                        web montage
# 1292  Web montage url -not working | TTS_CRM_NAM_PRO...
# 1293  http://eqitrspsnj1.nam.nsroot.net:8181/-  Webm...
# 1294                                 web Montage Access
# 1295  [20181112: ZD210049, ONGOING] URGENT - Busines...
# 1296                         Webslinger Setup Reference
# 1297   Webslinger and action script for Solace gateways
#
#                                             Description  \
# 0     Could  you please help to check and advise why...
# 1     Hi Support Team, \r\n\r\nThere seems to be an ...
# 2     Hi Carlo,\r\n\r\nWe executed the same query in...
# 3     ITRS PROD gateway(TTS_ELK_NAM_PROD) is not acc...
# 4     The new ITRS  gateway created is failing with ...
# 5     This is continuation of INC0055588345 - Please...
# 6     Hi Jignisha/fazil,\r\nAs discussed on call/IM,...
# 7     ELK not collecting alerts from TTS_FLEXCUBE_NA...
# 8     Hi ITRS Team,\r\n\r\nNew resources were added ...
# 9     Hi ITRS Team,\r\n\r\nNew resources were added ...
# 10    Same issue is happening in 2 PROD gateways\r\n...
# 11    Hi ITRS Team,\r\n\r\nNew resources were added ...
# 12    We added some users to the L1 group yesterday,...
# 13    Can you please help check the entitlement issu...
# 14    Hi Team,\r\nCould you please help to refresh t...
# 15    Hi ITRS team,\r\n\r\nGateway : TTS_LMS1_NAM_PR...
# 16    Please change the port to 7136 / 7137 so that ...
# 17    Gateway: MSST_REGIONAL2_LATAM_PROD\r\n\r\nI´m ...
# 18    Hi ITRS team,\r\n\r\nFor Gateway : TTS_LMS1_NA...
# 19    I have ran a synch yesterday and today on TTS_...
# 20    I understand that ITRS support team do not sup...
# 21    rdcgtsncsaa01p : Critical : ITM6K20 : ITM6_K20...
# 22    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 23    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 24    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 25    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 26    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 27    Full title: hdcicgitvld01c : Filesystem /var f...
# 28    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 29    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# ...                                                 ...
# 1268  ITRS platform team,\r\n\r\nThe global health c...
# 1269  Hi ITRS team, \r\n\r\nI would like to acquire ...
# 1270  Hi Team,\r\n   Raising the Incident  to update...
# 1271  We have multiple gateway's in our ITRS web das...
# 1272  We have multiple gateway's in our ITRS web das...
# 1273      ITRS Web Dashboard Upload | ISG | Web Dash...
# 1274  Hi team, \r\n\r\nDashboard http://lswitrswsap1...
# 1275  Hi Team,\r\nRaising this Incident to update We...
# 1276  ITRS Web Dashboard Upload | ISG | Web Dashboar...
# 1277  Web dashboard URL is not responding to request...
# 1278  Hi Team,\r\n\r\nPlease load the attached Dashb...
# 1279  dashboard doesn't load, please check attached ...
# 1280  Hi Team,\r\nRaising this Incident to upload We...
# 1281  ITRS Support - Our FX Velocity SOW Dashboard i...
# 1282  Please consider problem where ALL dashboards a...
# 1283  Please update CS web dashboard with the attach...
# 1284  Hi Team,\r\n\r\nWe are having an issue with be...
# 1285  ITRS web dashboard not linking\r\nhttp://lswit...
# 1286  Trying to migrate data views on montage with c...
# 1287  I tried with two:\r\n\r\nttscrmdev\r\ncrmuat\r...
# 1288  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1289  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1290  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1291  Yes we'd like it for a few of our gateway. \r\...
# 1292  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1293  http://eqitrspsnj1.nam.nsroot.net:8181/-  Webm...
# 1294  Hi Team,\r\n\r\nOur L0 can access below web mo...
# 1295  We have a critical trading dashboard for our t...
# 1296  Hi Team,\r\nWe are trying to build the webslin...
# 1297  Please help us setup Webslinger and Gateway 2 ...
#
#                           CATEGORY  \
# 0                    Bespoke - ELK
# 1                    Bespoke - ELK
# 2                    Bespoke - ELK
# 3                    Bespoke - ELK
# 4                    Bespoke - ELK
# 5                    Bespoke - ELK
# 6                    Bespoke - ELK
# 7                    Bespoke - ELK
# 8           Bespoke - Gateway Sync
# 9           Bespoke - Gateway Sync
# 10          Bespoke - Gateway Sync
# 11          Bespoke - Gateway Sync
# 12          Bespoke - Gateway Sync
# 13          Bespoke - Gateway Sync
# 14          Bespoke - Gateway Sync
# 15          Bespoke - Gateway Sync
# 16          Bespoke - Gateway Sync
# 17          Bespoke - Gateway Sync
# 18          Bespoke - Gateway Sync
# 19          Bespoke - Gateway Sync
# 20          Bespoke - Gateway Sync
# 21          Bespoke - Health Check
# 22          Bespoke - Health Check
# 23          Bespoke - Health Check
# 24          Bespoke - Health Check
# 25          Bespoke - Health Check
# 26          Bespoke - Health Check
# 27          Bespoke - Health Check
# 28          Bespoke - Health Check
# 29          Bespoke - Health Check
# ...                            ...
# 1268  Visualisation - WebDashboard
# 1269  Visualisation - WebDashboard
# 1270  Visualisation - WebDashboard
# 1271  Visualisation - WebDashboard
# 1272  Visualisation - WebDashboard
# 1273  Visualisation - WebDashboard
# 1274  Visualisation - WebDashboard
# 1275  Visualisation - WebDashboard
# 1276  Visualisation - WebDashboard
# 1277  Visualisation - WebDashboard
# 1278  Visualisation - WebDashboard
# 1279  Visualisation - WebDashboard
# 1280  Visualisation - WebDashboard
# 1281  Visualisation - WebDashboard
# 1282  Visualisation - WebDashboard
# 1283  Visualisation - WebDashboard
# 1284  Visualisation - WebDashboard
# 1285  Visualisation - WebDashboard
# 1286    Visualisation - WebMontage
# 1287    Visualisation - WebMontage
# 1288    Visualisation - WebMontage
# 1289    Visualisation - WebMontage
# 1290    Visualisation - WebMontage
# 1291    Visualisation - WebMontage
# 1292    Visualisation - WebMontage
# 1293    Visualisation - WebMontage
# 1294    Visualisation - WebMontage
# 1295    Visualisation - WebSlinger
# 1296    Visualisation - WebSlinger
# 1297    Visualisation - WebSlinger
#
#                                   title_and_description
# 0     ('Missing ELK Records for Gateway MSST_CRDS_NA...
# 1     ('Issue with ELK Alert Sync', 'Hi Support Team...
# 2     ('RE: Inconsistent ELK data', 'Hi Carlo,\n\nWe...
# 3     ('Prod Gateway TTS_ELK_NAM_PROD not accessible...
# 4     ('Authentication failure with new ITRS gateway...
# 5     ('GCE : Getting  ELK alerts for Zero rows', 'T...
# 6     ('GCE : Getting  ELK alerts', 'Hi Jignisha/faz...
# 7     ('ELK not collecting alerts from TTS_FLEXCUBE_...
# 8     ('Sync ITRS gateways for Trade', 'Hi ITRS Team...
# 9     ('Sync ITRS gateways for Trade ', 'Hi ITRS Tea...
# 10    ('PROD Gateway Entitlement SYNC Issues | Multi...
# 11    ('Sync ITRS gateways for channels | ', 'Hi ITR...
# 12    ('Entitlement sync issue | TTS_GPCD_GBS_STARS_...
# 13    ('entitlement issue for MSST_CRDS_NAM_PROD', '...
# 14    ('Entitlement sync for CPB_EMEA_APAC_PROD gate...
# 15    ('ITRS : Sync Issue : TTS_LMS1_NAM_PROD', 'Hi ...
# 16    ('Change the port to 7136 / 7137 so that NetPr...
# 17    ('[20181012: PENDING ENGG] Not  able to create...
# 18    ('ITRS : Sync Issue : TTS_LMS1_NAM_PROD SN# IN...
# 19    ('users not getting added during the synch', '...
# 20    ('ITRS monitoring - {ENV - PROD or COB} enviro...
# 21    ('rdcgtsncsaa01p : ITM6_K20:alert on process n...
# 22    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# 23    ('lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdic...
# 24    ('lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdic...
# 25    ('lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdic...
# 26    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# 27    ('hdcicgitvld01c : Filesystem /var free space ...
# 28    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# 29    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# ...                                                 ...
# 1268  ('GHC webdashboard not working | TTS | Dashboa...
# 1269  ('Unable to load ITRS from web url', 'Hi ITRS ...
# 1270  ('Uploading XMC ETL Dashboard', 'Hi Team,\n   ...
# 1271  ("ITRS Web Dashboard - Few gateway's not worki...
# 1272  ("ITRS Web Dashboard - Few gateway's not worki...
# 1273  ('Web Dashboard Hosting | ISG_PRODUCT_NAM_PROD...
# 1274  ('Stale web dashboard not displaying correct i...
# 1275  ('Update XMC UI Dashboard', 'Hi Team,\nRaising...
# 1276  ('Upload XMC QV Dashboards', 'ITRS Web Dashboa...
# 1277  ('http://itrsswcob2:8093/ | Web dashboard URL ...
# 1278  ('WEB Dashboard BO', 'Hi Team,\n\nPlease load ...
# 1279  ("Dashboard doesn't load, please check attache...
# 1280  ('Upload XMC UI Dashboards', 'Hi Team,\nRaisin...
# 1281  ('FX Velocity: SOW ITRS Dashboard - Stale', 'I...
# 1282  ('[RCA ] Web Dashboard Unavailability Issue', ...
# 1283  ('CS - Web dashboard update', 'Please update C...
# 1284  ('Web dashboard issue - DDE | TTS | Web Dashbo...
# 1285  ('ALL - MAINT - ITRS Web dashboard issue', 'IT...
# 1286  ('Few Data views not visible on montage', "Try...
# 1287  ('COB Web montage url -None of the credentials...
# 1288  ('Web montage url -not working', 'Hi ITRS Team...
# 1289  ('**URGENT** Web montage url -not working', 'H...
# 1290  ('Web montage url -not working', 'Hi ITRS Team...
# 1291  ('web montage', "Yes we'd like it for a few of...
# 1292  ('Web montage url -not working | TTS_CRM_NAM_P...
# 1293  ('http://eqitrspsnj1.nam.nsroot.net:8181/-  We...
# 1294  ('web Montage Access', "Hi Team,\n\nOur L0 can...
# 1295  ('[20181112: ZD210049, ONGOING] URGENT - Busin...
# 1296  ('Webslinger Setup Reference', 'Hi Team,\nWe a...
# 1297  ('Webslinger and action script for Solace gate...
#
# [1298 rows x 6 columns]

# %%
from io import StringIO
col = ['CATEGORY', 'title_and_description']
tr_data = tr_data[col]
tr_data = tr_data[pd.notnull(tr_data['title_and_description'])]
tr_data.columns = ['CATEGORY', 'title_and_description']
tr_data['Number'] = tr_data['CATEGORY'].factorize()[0]
category_id_df = tr_data[['CATEGORY', 'Number']].drop_duplicates().sort_values('Number')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['Number', 'CATEGORY']].values)
tr_data.head()
# Out:
#         CATEGORY                              title_and_description  Number
# 0  Bespoke - ELK  ('Missing ELK Records for Gateway MSST_CRDS_NA...       0
# 1  Bespoke - ELK  ('Issue with ELK Alert Sync', 'Hi Support Team...       0
# 2  Bespoke - ELK  ('RE: Inconsistent ELK data', 'Hi Carlo,\n\nWe...       0
# 3  Bespoke - ELK  ('Prod Gateway TTS_ELK_NAM_PROD not accessible...       0
# 4  Bespoke - ELK  ('Authentication failure with new ITRS gateway...       0

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
tr_data.groupby('CATEGORY').title_and_description.count().plot.bar(ylim=0)
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(tr_data.title_and_description).toarray()
labels = tr_data.Number
features.shape
# Out:
# (1298, 2938)

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC

X_train, X_test, y_train, y_test = train_test_split(tr_data['title_and_description'], tr_data['CATEGORY'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)
svc = LinearSVC().fit(X_train_tfidf, y_train)

# %%
print(svc.predict(count_vect.transform(["itrs down"])))
# Out:
# ['Netprobe - Troubleshooting']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 2
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
import seaborn as sns
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
# Out:
# C:\Users\scervantes\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=2.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\scervantes\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=2.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\scervantes\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=2.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\scervantes\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=2.
#   % (min_groups, self.n_splits)), Warning)

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 0.835121
# LogisticRegression        0.683594
# MultinomialNB             0.609832
# RandomForestClassifier    0.396855
# Name: accuracy, dtype: float64

# %%
model = LinearSVC()
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, tr_data.index, test_size=0.4, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.CATEGORY.values, yticklabels=category_id_df.CATEGORY.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred, target_names=tr_data['CATEGORY'].unique()))
# Out:
#                                                precision    recall  f1-score   support
#
#                                 Bespoke - ELK       1.00      1.00      1.00         3
#                        Bespoke - Gateway Sync       1.00      0.50      0.67         8
#                        Bespoke - Health Check       1.00      1.00      1.00        31
#                  Bespoke - Technology Toolbar       1.00      1.00      1.00         2
#                          Bespoke - Wais Token       0.79      0.94      0.86        36
#                        Gateway - Active Times       0.79      0.61      0.69        18
#                      Gateway - Authentication       0.72      0.75      0.74        28
#                            Gateway - Commands       0.00      0.00      0.00         2
# Gateway - Data Quality and Performance Tuning       0.60      1.00      0.75         3
#                    Gateway - Database Logging       1.00      0.50      0.67         4
#                         Gateway - Hot Standby       0.00      0.00      0.00         2
#                        Gateway - Installation       0.42      0.62      0.50         8
#                    Gateway - Managed Entities       0.00      0.00      0.00         1
#                              Gateway - Others       0.75      0.60      0.67        10
#                              Gateway - Probes       1.00      0.89      0.94         9
#           Gateway - Rules, Actions and Alerts       0.00      0.00      0.00         1
#                         Gateway - Setup Files       0.00      0.00      0.00         2
#                             Gateway - Sharing       0.89      0.98      0.93       163
#                              License - Expiry       0.87      0.68      0.76        19
#                     License - Troubleshooting       0.75      0.91      0.83        70
#                       Netprobe - Installation       0.78      0.70      0.74        10
#                             Netprobe - Others       0.00      0.00      0.00         1
#                    Netprobe - Troubleshooting       0.80      0.57      0.67        21
#          Plugin - API and Development Toolkit       0.00      0.00      0.00         5
#                             Plugin - Database       0.00      0.00      0.00         1
#                      Plugin - File Monitoring       0.00      0.00      0.00         1
#                      Plugin - Message Tracker       1.00      1.00      1.00         1
#                           Plugin - Middleware       0.00      0.00      0.00         3
#                               Plugin - Others       0.00      0.00      0.00        11
#                               Plugin - System       0.80      0.98      0.88        41
#                      Plugin - System Hardware       1.00      0.67      0.80         3
#                       Plugin - System Windows       0.00      0.00      0.00         2
#
#                                   avg / total       0.78      0.82      0.80       520
# C:\Users\scervantes\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1428: UserWarning: labels size, 32, does not match size of target_names, 37
#   .format(len(labels), len(target_names))
# C:\Users\scervantes\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
test_set = pd.read_csv('categorizationdata_withtad.csv', encoding="latin1")
test_set
# Out:
#       Unnamed: 0         Number  \
# 0              0  INC0059672965
# 1              1  INC0058335285
# 2              2  INC0057358766
# 3              3  INC0057388669
# 4              4  INC0057046947
# 5              5  INC0055908871
# 6              6  INC0055588345
# 7              7  INC0055563666
# 8              8  INC0059603741
# 9              9  INC0059292483
# 10            10  INC0058944579
# 11            11  INC0059263252
# 12            12  INC0059171980
# 13            13  INC0058683413
# 14            14  INC0058092741
# 15            15  INC0057049141
# 16            16  INC0057265001
# 17            17  INC0057041545
# 18            18  INC0057049313
# 19            19  INC0055910058
# 20            20  INC0055527766
# 21            21  INC0059857722
# 22            22  INC0059882981
# 23            23  INC0059943875
# 24            24  INC0059945178
# 25            25  INC0059828610
# 26            26  INC0059794089
# 27            27  INC0059920369
# 28            28  INC0059729274
# 29            29  INC0059857245
# ...          ...            ...
# 1268        1268  INC0056097051
# 1269        1269  INC0055909605
# 1270        1270  INC0056052775
# 1271        1271  INC0056040160
# 1272        1272  INC0056038884
# 1273        1273  INC0055982523
# 1274        1274  INC0055826223
# 1275        1275  INC0055941821
# 1276        1276  INC0055906603
# 1277        1277  INC0055757860
# 1278        1278  INC0055850592
# 1279        1279  INC0055657315
# 1280        1280  INC0055787326
# 1281        1281  INC0055633270
# 1282        1282  INC0055469800
# 1283        1283  INC0055709555
# 1284        1284  INC0055485710
# 1285        1285  INC0055559171
# 1286        1286  INC0059945718
# 1287        1287  INC0059736383
# 1288        1288  INC0059721068
# 1289        1289  INC0058887752
# 1290        1290  INC0058037386
# 1291        1291  INC0056707987
# 1292        1292  INC0056487009
# 1293        1293  INC0056198886
# 1294        1294  INC0056046473
# 1295        1295  INC0056691767
# 1296        1296  INC0057487375
# 1297        1297  INC0056735990
#
#                                                   Title  \
# 0     Missing ELK Records for Gateway MSST_CRDS_NAM_...
# 1                             Issue with ELK Alert Sync
# 2                             RE: Inconsistent ELK data
# 3     Prod Gateway TTS_ELK_NAM_PROD not accessible |...
# 4     Authentication failure with new ITRS gateway |...
# 5               GCE : Getting  ELK alerts for Zero rows
# 6                             GCE : Getting  ELK alerts
# 7     ELK not collecting alerts from TTS_FLEXCUBE_NA...
# 8                          Sync ITRS gateways for Trade
# 9                         Sync ITRS gateways for Trade
# 10    PROD Gateway Entitlement SYNC Issues | Multipl...
# 11                   Sync ITRS gateways for channels |
# 12    Entitlement sync issue | TTS_GPCD_GBS_STARS_IV...
# 13             entitlement issue for MSST_CRDS_NAM_PROD
# 14      Entitlement sync for CPB_EMEA_APAC_PROD gateway
# 15                ITRS : Sync Issue : TTS_LMS1_NAM_PROD
# 16    Change the port to 7136 / 7137 so that NetProb...
# 17    [20181012: PENDING ENGG] Not  able to create S...
# 18    ITRS : Sync Issue : TTS_LMS1_NAM_PROD SN# INC0...
# 19             users not getting added during the synch
# 20    ITRS monitoring - {ENV - PROD or COB} environm...
# 21    rdcgtsncsaa01p : ITM6_K20:alert on process net...
# 22    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 23    lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 24    lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 25    lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 26    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 27    hdcicgitvld01c : Filesystem /var free space is...
# 28    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 29    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# ...                                                 ...
# 1268  GHC webdashboard not working | TTS | Dashboard...
# 1269                   Unable to load ITRS from web url
# 1270                        Uploading XMC ETL Dashboard
# 1271  ITRS Web Dashboard - Few gateway's not working...
# 1272  ITRS Web Dashboard - Few gateway's not working...
# 1273  Web Dashboard Hosting | ISG_PRODUCT_NAM_PROD |...
# 1274  Stale web dashboard not displaying correct inf...
# 1275                            Update XMC UI Dashboard
# 1276                           Upload XMC QV Dashboards
# 1277  http://itrsswcob2:8093/ | Web dashboard URL no...
# 1278                                   WEB Dashboard BO
# 1279  Dashboard doesn't load, please check attached ...
# 1280                           Upload XMC UI Dashboards
# 1281            FX Velocity: SOW ITRS Dashboard - Stale
# 1282          [RCA ] Web Dashboard Unavailability Issue
# 1283                          CS - Web dashboard update
# 1284  Web dashboard issue - DDE | TTS | Web Dashboar...
# 1285             ALL - MAINT - ITRS Web dashboard issue
# 1286              Few Data views not visible on montage
# 1287  COB Web montage url -None of the credentials a...
# 1288                       Web montage url -not working
# 1289            **URGENT** Web montage url -not working
# 1290                       Web montage url -not working
# 1291                                        web montage
# 1292  Web montage url -not working | TTS_CRM_NAM_PRO...
# 1293  http://eqitrspsnj1.nam.nsroot.net:8181/-  Webm...
# 1294                                 web Montage Access
# 1295  [20181112: ZD210049, ONGOING] URGENT - Busines...
# 1296                         Webslinger Setup Reference
# 1297   Webslinger and action script for Solace gateways
#
#                                             Description  \
# 0     Could  you please help to check and advise why...
# 1     Hi Support Team, \r\n\r\nThere seems to be an ...
# 2     Hi Carlo,\r\n\r\nWe executed the same query in...
# 3     ITRS PROD gateway(TTS_ELK_NAM_PROD) is not acc...
# 4     The new ITRS  gateway created is failing with ...
# 5     This is continuation of INC0055588345 - Please...
# 6     Hi Jignisha/fazil,\r\nAs discussed on call/IM,...
# 7     ELK not collecting alerts from TTS_FLEXCUBE_NA...
# 8     Hi ITRS Team,\r\n\r\nNew resources were added ...
# 9     Hi ITRS Team,\r\n\r\nNew resources were added ...
# 10    Same issue is happening in 2 PROD gateways\r\n...
# 11    Hi ITRS Team,\r\n\r\nNew resources were added ...
# 12    We added some users to the L1 group yesterday,...
# 13    Can you please help check the entitlement issu...
# 14    Hi Team,\r\nCould you please help to refresh t...
# 15    Hi ITRS team,\r\n\r\nGateway : TTS_LMS1_NAM_PR...
# 16    Please change the port to 7136 / 7137 so that ...
# 17    Gateway: MSST_REGIONAL2_LATAM_PROD\r\n\r\nIÂ´m...
# 18    Hi ITRS team,\r\n\r\nFor Gateway : TTS_LMS1_NA...
# 19    I have ran a synch yesterday and today on TTS_...
# 20    I understand that ITRS support team do not sup...
# 21    rdcgtsncsaa01p : Critical : ITM6K20 : ITM6_K20...
# 22    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 23    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 24    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 25    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 26    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 27    Full title: hdcicgitvld01c : Filesystem /var f...
# 28    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 29    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# ...                                                 ...
# 1268  ITRS platform team,\r\n\r\nThe global health c...
# 1269  Hi ITRS team, \r\n\r\nI would like to acquire ...
# 1270  Hi Team,\r\n   Raising the Incident  to update...
# 1271  We have multiple gateway's in our ITRS web das...
# 1272  We have multiple gateway's in our ITRS web das...
# 1273      ITRS Web Dashboard Upload | ISG | Web Dash...
# 1274  Hi team, \r\n\r\nDashboard http://lswitrswsap1...
# 1275  Hi Team,\r\nRaising this Incident to update We...
# 1276  ITRS Web Dashboard Upload | ISG | Web Dashboar...
# 1277  Web dashboard URL is not responding to request...
# 1278  Hi Team,\r\n\r\nPlease load the attached Dashb...
# 1279  dashboard doesn't load, please check attached ...
# 1280  Hi Team,\r\nRaising this Incident to upload We...
# 1281  ITRS Support - Our FX Velocity SOW Dashboard i...
# 1282  Please consider problem where ALL dashboards a...
# 1283  Please update CS web dashboard with the attach...
# 1284  Hi Team,\r\n\r\nWe are having an issue with be...
# 1285  ITRS web dashboard not linking\r\nhttp://lswit...
# 1286  Trying to migrate data views on montage with c...
# 1287  I tried with two:\r\n\r\nttscrmdev\r\ncrmuat\r...
# 1288  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1289  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1290  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1291  Yes we'd like it for a few of our gateway. \r\...
# 1292  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1293  http://eqitrspsnj1.nam.nsroot.net:8181/-  Webm...
# 1294  Hi Team,\r\n\r\nOur L0 can access below web mo...
# 1295  We have a critical trading dashboard for our t...
# 1296  Hi Team,\r\nWe are trying to build the webslin...
# 1297  Please help us setup Webslinger and Gateway 2 ...
#
#                           CATEGORY  \
# 0                    Bespoke - ELK
# 1                    Bespoke - ELK
# 2                    Bespoke - ELK
# 3                    Bespoke - ELK
# 4                    Bespoke - ELK
# 5                    Bespoke - ELK
# 6                    Bespoke - ELK
# 7                    Bespoke - ELK
# 8           Bespoke - Gateway Sync
# 9           Bespoke - Gateway Sync
# 10          Bespoke - Gateway Sync
# 11          Bespoke - Gateway Sync
# 12          Bespoke - Gateway Sync
# 13          Bespoke - Gateway Sync
# 14          Bespoke - Gateway Sync
# 15          Bespoke - Gateway Sync
# 16          Bespoke - Gateway Sync
# 17          Bespoke - Gateway Sync
# 18          Bespoke - Gateway Sync
# 19          Bespoke - Gateway Sync
# 20          Bespoke - Gateway Sync
# 21          Bespoke - Health Check
# 22          Bespoke - Health Check
# 23          Bespoke - Health Check
# 24          Bespoke - Health Check
# 25          Bespoke - Health Check
# 26          Bespoke - Health Check
# 27          Bespoke - Health Check
# 28          Bespoke - Health Check
# 29          Bespoke - Health Check
# ...                            ...
# 1268  Visualisation - WebDashboard
# 1269  Visualisation - WebDashboard
# 1270  Visualisation - WebDashboard
# 1271  Visualisation - WebDashboard
# 1272  Visualisation - WebDashboard
# 1273  Visualisation - WebDashboard
# 1274  Visualisation - WebDashboard
# 1275  Visualisation - WebDashboard
# 1276  Visualisation - WebDashboard
# 1277  Visualisation - WebDashboard
# 1278  Visualisation - WebDashboard
# 1279  Visualisation - WebDashboard
# 1280  Visualisation - WebDashboard
# 1281  Visualisation - WebDashboard
# 1282  Visualisation - WebDashboard
# 1283  Visualisation - WebDashboard
# 1284  Visualisation - WebDashboard
# 1285  Visualisation - WebDashboard
# 1286    Visualisation - WebMontage
# 1287    Visualisation - WebMontage
# 1288    Visualisation - WebMontage
# 1289    Visualisation - WebMontage
# 1290    Visualisation - WebMontage
# 1291    Visualisation - WebMontage
# 1292    Visualisation - WebMontage
# 1293    Visualisation - WebMontage
# 1294    Visualisation - WebMontage
# 1295    Visualisation - WebSlinger
# 1296    Visualisation - WebSlinger
# 1297    Visualisation - WebSlinger
#
#                                   title_and_description
# 0     ('Missing ELK Records for Gateway MSST_CRDS_NA...
# 1     ('Issue with ELK Alert Sync', 'Hi Support Team...
# 2     ('RE: Inconsistent ELK data', 'Hi Carlo,\n\nWe...
# 3     ('Prod Gateway TTS_ELK_NAM_PROD not accessible...
# 4     ('Authentication failure with new ITRS gateway...
# 5     ('GCE : Getting  ELK alerts for Zero rows', 'T...
# 6     ('GCE : Getting  ELK alerts', 'Hi Jignisha/faz...
# 7     ('ELK not collecting alerts from TTS_FLEXCUBE_...
# 8     ('Sync ITRS gateways for Trade', 'Hi ITRS Team...
# 9     ('Sync ITRS gateways for Trade ', 'Hi ITRS Tea...
# 10    ('PROD Gateway Entitlement SYNC Issues | Multi...
# 11    ('Sync ITRS gateways for channels | ', 'Hi ITR...
# 12    ('Entitlement sync issue | TTS_GPCD_GBS_STARS_...
# 13    ('entitlement issue for MSST_CRDS_NAM_PROD', '...
# 14    ('Entitlement sync for CPB_EMEA_APAC_PROD gate...
# 15    ('ITRS : Sync Issue : TTS_LMS1_NAM_PROD', 'Hi ...
# 16    ('Change the port to 7136 / 7137 so that NetPr...
# 17    ('[20181012: PENDING ENGG] Not  able to create...
# 18    ('ITRS : Sync Issue : TTS_LMS1_NAM_PROD SN# IN...
# 19    ('users not getting added during the synch', '...
# 20    ('ITRS monitoring - {ENV - PROD or COB} enviro...
# 21    ('rdcgtsncsaa01p : ITM6_K20:alert on process n...
# 22    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# 23    ('lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdic...
# 24    ('lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdic...
# 25    ('lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdic...
# 26    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# 27    ('hdcicgitvld01c : Filesystem /var free space ...
# 28    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# 29    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# ...                                                 ...
# 1268  ('GHC webdashboard not working | TTS | Dashboa...
# 1269  ('Unable to load ITRS from web url', 'Hi ITRS ...
# 1270  ('Uploading XMC ETL Dashboard', 'Hi Team,\n   ...
# 1271  ("ITRS Web Dashboard - Few gateway's not worki...
# 1272  ("ITRS Web Dashboard - Few gateway's not worki...
# 1273  ('Web Dashboard Hosting | ISG_PRODUCT_NAM_PROD...
# 1274  ('Stale web dashboard not displaying correct i...
# 1275  ('Update XMC UI Dashboard', 'Hi Team,\nRaising...
# 1276  ('Upload XMC QV Dashboards', 'ITRS Web Dashboa...
# 1277  ('http://itrsswcob2:8093/ | Web dashboard URL ...
# 1278  ('WEB Dashboard BO', 'Hi Team,\n\nPlease load ...
# 1279  ("Dashboard doesn't load, please check attache...
# 1280  ('Upload XMC UI Dashboards', 'Hi Team,\nRaisin...
# 1281  ('FX Velocity: SOW ITRS Dashboard - Stale', 'I...
# 1282  ('[RCA ] Web Dashboard Unavailability Issue', ...
# 1283  ('CS - Web dashboard update', 'Please update C...
# 1284  ('Web dashboard issue - DDE | TTS | Web Dashbo...
# 1285  ('ALL - MAINT - ITRS Web dashboard issue', 'IT...
# 1286  ('Few Data views not visible on montage', "Try...
# 1287  ('COB Web montage url -None of the credentials...
# 1288  ('Web montage url -not working', 'Hi ITRS Team...
# 1289  ('**URGENT** Web montage url -not working', 'H...
# 1290  ('Web montage url -not working', 'Hi ITRS Team...
# 1291  ('web montage', "Yes we'd like it for a few of...
# 1292  ('Web montage url -not working | TTS_CRM_NAM_P...
# 1293  ('http://eqitrspsnj1.nam.nsroot.net:8181/-  We...
# 1294  ('web Montage Access', "Hi Team,\n\nOur L0 can...
# 1295  ('[20181112: ZD210049, ONGOING] URGENT - Busin...
# 1296  ('Webslinger Setup Reference', 'Hi Team,\nWe a...
# 1297  ('Webslinger and action script for Solace gate...
#
# [1298 rows x 6 columns]

# %%
test_set['Combined MNB New Predicted Values'] = clf.predict(count_vect.transform(test_set['title_and_description'].values.astype('U')))

# %%
test_set['Combined SVC New Predicted Values'] = svc.predict(count_vect.transform(test_set['title_and_description'].values.astype('U')))

# %%
test_set['Title MNB New Predicted Values'] = clf.predict(count_vect.transform(test_set['Title'].values.astype('U')))

# %%
test_set['Title SVC New Predicted Values'] = svc.predict(count_vect.transform(test_set['Title'].values.astype('U')))

# %%
test_set
# Out:
#       Unnamed: 0         Number  \
# 0              0  INC0059672965
# 1              1  INC0058335285
# 2              2  INC0057358766
# 3              3  INC0057388669
# 4              4  INC0057046947
# 5              5  INC0055908871
# 6              6  INC0055588345
# 7              7  INC0055563666
# 8              8  INC0059603741
# 9              9  INC0059292483
# 10            10  INC0058944579
# 11            11  INC0059263252
# 12            12  INC0059171980
# 13            13  INC0058683413
# 14            14  INC0058092741
# 15            15  INC0057049141
# 16            16  INC0057265001
# 17            17  INC0057041545
# 18            18  INC0057049313
# 19            19  INC0055910058
# 20            20  INC0055527766
# 21            21  INC0059857722
# 22            22  INC0059882981
# 23            23  INC0059943875
# 24            24  INC0059945178
# 25            25  INC0059828610
# 26            26  INC0059794089
# 27            27  INC0059920369
# 28            28  INC0059729274
# 29            29  INC0059857245
# ...          ...            ...
# 1268        1268  INC0056097051
# 1269        1269  INC0055909605
# 1270        1270  INC0056052775
# 1271        1271  INC0056040160
# 1272        1272  INC0056038884
# 1273        1273  INC0055982523
# 1274        1274  INC0055826223
# 1275        1275  INC0055941821
# 1276        1276  INC0055906603
# 1277        1277  INC0055757860
# 1278        1278  INC0055850592
# 1279        1279  INC0055657315
# 1280        1280  INC0055787326
# 1281        1281  INC0055633270
# 1282        1282  INC0055469800
# 1283        1283  INC0055709555
# 1284        1284  INC0055485710
# 1285        1285  INC0055559171
# 1286        1286  INC0059945718
# 1287        1287  INC0059736383
# 1288        1288  INC0059721068
# 1289        1289  INC0058887752
# 1290        1290  INC0058037386
# 1291        1291  INC0056707987
# 1292        1292  INC0056487009
# 1293        1293  INC0056198886
# 1294        1294  INC0056046473
# 1295        1295  INC0056691767
# 1296        1296  INC0057487375
# 1297        1297  INC0056735990
#
#                                                   Title  \
# 0     Missing ELK Records for Gateway MSST_CRDS_NAM_...
# 1                             Issue with ELK Alert Sync
# 2                             RE: Inconsistent ELK data
# 3     Prod Gateway TTS_ELK_NAM_PROD not accessible |...
# 4     Authentication failure with new ITRS gateway |...
# 5               GCE : Getting  ELK alerts for Zero rows
# 6                             GCE : Getting  ELK alerts
# 7     ELK not collecting alerts from TTS_FLEXCUBE_NA...
# 8                          Sync ITRS gateways for Trade
# 9                         Sync ITRS gateways for Trade
# 10    PROD Gateway Entitlement SYNC Issues | Multipl...
# 11                   Sync ITRS gateways for channels |
# 12    Entitlement sync issue | TTS_GPCD_GBS_STARS_IV...
# 13             entitlement issue for MSST_CRDS_NAM_PROD
# 14      Entitlement sync for CPB_EMEA_APAC_PROD gateway
# 15                ITRS : Sync Issue : TTS_LMS1_NAM_PROD
# 16    Change the port to 7136 / 7137 so that NetProb...
# 17    [20181012: PENDING ENGG] Not  able to create S...
# 18    ITRS : Sync Issue : TTS_LMS1_NAM_PROD SN# INC0...
# 19             users not getting added during the synch
# 20    ITRS monitoring - {ENV - PROD or COB} environm...
# 21    rdcgtsncsaa01p : ITM6_K20:alert on process net...
# 22    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 23    lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 24    lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 25    lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdicgi...
# 26    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 27    hdcicgitvld01c : Filesystem /var free space is...
# 28    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# 29    lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdicgi...
# ...                                                 ...
# 1268  GHC webdashboard not working | TTS | Dashboard...
# 1269                   Unable to load ITRS from web url
# 1270                        Uploading XMC ETL Dashboard
# 1271  ITRS Web Dashboard - Few gateway's not working...
# 1272  ITRS Web Dashboard - Few gateway's not working...
# 1273  Web Dashboard Hosting | ISG_PRODUCT_NAM_PROD |...
# 1274  Stale web dashboard not displaying correct inf...
# 1275                            Update XMC UI Dashboard
# 1276                           Upload XMC QV Dashboards
# 1277  http://itrsswcob2:8093/ | Web dashboard URL no...
# 1278                                   WEB Dashboard BO
# 1279  Dashboard doesn't load, please check attached ...
# 1280                           Upload XMC UI Dashboards
# 1281            FX Velocity: SOW ITRS Dashboard - Stale
# 1282          [RCA ] Web Dashboard Unavailability Issue
# 1283                          CS - Web dashboard update
# 1284  Web dashboard issue - DDE | TTS | Web Dashboar...
# 1285             ALL - MAINT - ITRS Web dashboard issue
# 1286              Few Data views not visible on montage
# 1287  COB Web montage url -None of the credentials a...
# 1288                       Web montage url -not working
# 1289            **URGENT** Web montage url -not working
# 1290                       Web montage url -not working
# 1291                                        web montage
# 1292  Web montage url -not working | TTS_CRM_NAM_PRO...
# 1293  http://eqitrspsnj1.nam.nsroot.net:8181/-  Webm...
# 1294                                 web Montage Access
# 1295  [20181112: ZD210049, ONGOING] URGENT - Busines...
# 1296                         Webslinger Setup Reference
# 1297   Webslinger and action script for Solace gateways
#
#                                             Description  \
# 0     Could  you please help to check and advise why...
# 1     Hi Support Team, \r\n\r\nThere seems to be an ...
# 2     Hi Carlo,\r\n\r\nWe executed the same query in...
# 3     ITRS PROD gateway(TTS_ELK_NAM_PROD) is not acc...
# 4     The new ITRS  gateway created is failing with ...
# 5     This is continuation of INC0055588345 - Please...
# 6     Hi Jignisha/fazil,\r\nAs discussed on call/IM,...
# 7     ELK not collecting alerts from TTS_FLEXCUBE_NA...
# 8     Hi ITRS Team,\r\n\r\nNew resources were added ...
# 9     Hi ITRS Team,\r\n\r\nNew resources were added ...
# 10    Same issue is happening in 2 PROD gateways\r\n...
# 11    Hi ITRS Team,\r\n\r\nNew resources were added ...
# 12    We added some users to the L1 group yesterday,...
# 13    Can you please help check the entitlement issu...
# 14    Hi Team,\r\nCould you please help to refresh t...
# 15    Hi ITRS team,\r\n\r\nGateway : TTS_LMS1_NAM_PR...
# 16    Please change the port to 7136 / 7137 so that ...
# 17    Gateway: MSST_REGIONAL2_LATAM_PROD\r\n\r\nIÂ´m...
# 18    Hi ITRS team,\r\n\r\nFor Gateway : TTS_LMS1_NA...
# 19    I have ran a synch yesterday and today on TTS_...
# 20    I understand that ITRS support team do not sup...
# 21    rdcgtsncsaa01p : Critical : ITM6K20 : ITM6_K20...
# 22    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 23    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 24    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 25    lfdicgitrdb1c : Critical : ITM6 : LZIOS_BP_Net...
# 26    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 27    Full title: hdcicgitvld01c : Filesystem /var f...
# 28    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# 29    lrdicgitrdb1p : Critical : ITM6 : LZIOS_BP_Net...
# ...                                                 ...
# 1268  ITRS platform team,\r\n\r\nThe global health c...
# 1269  Hi ITRS team, \r\n\r\nI would like to acquire ...
# 1270  Hi Team,\r\n   Raising the Incident  to update...
# 1271  We have multiple gateway's in our ITRS web das...
# 1272  We have multiple gateway's in our ITRS web das...
# 1273      ITRS Web Dashboard Upload | ISG | Web Dash...
# 1274  Hi team, \r\n\r\nDashboard http://lswitrswsap1...
# 1275  Hi Team,\r\nRaising this Incident to update We...
# 1276  ITRS Web Dashboard Upload | ISG | Web Dashboar...
# 1277  Web dashboard URL is not responding to request...
# 1278  Hi Team,\r\n\r\nPlease load the attached Dashb...
# 1279  dashboard doesn't load, please check attached ...
# 1280  Hi Team,\r\nRaising this Incident to upload We...
# 1281  ITRS Support - Our FX Velocity SOW Dashboard i...
# 1282  Please consider problem where ALL dashboards a...
# 1283  Please update CS web dashboard with the attach...
# 1284  Hi Team,\r\n\r\nWe are having an issue with be...
# 1285  ITRS web dashboard not linking\r\nhttp://lswit...
# 1286  Trying to migrate data views on montage with c...
# 1287  I tried with two:\r\n\r\nttscrmdev\r\ncrmuat\r...
# 1288  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1289  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1290  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1291  Yes we'd like it for a few of our gateway. \r\...
# 1292  Hi ITRS Team,\r\n\r\nBelow web montage URL is ...
# 1293  http://eqitrspsnj1.nam.nsroot.net:8181/-  Webm...
# 1294  Hi Team,\r\n\r\nOur L0 can access below web mo...
# 1295  We have a critical trading dashboard for our t...
# 1296  Hi Team,\r\nWe are trying to build the webslin...
# 1297  Please help us setup Webslinger and Gateway 2 ...
#
#                           CATEGORY  \
# 0                    Bespoke - ELK
# 1                    Bespoke - ELK
# 2                    Bespoke - ELK
# 3                    Bespoke - ELK
# 4                    Bespoke - ELK
# 5                    Bespoke - ELK
# 6                    Bespoke - ELK
# 7                    Bespoke - ELK
# 8           Bespoke - Gateway Sync
# 9           Bespoke - Gateway Sync
# 10          Bespoke - Gateway Sync
# 11          Bespoke - Gateway Sync
# 12          Bespoke - Gateway Sync
# 13          Bespoke - Gateway Sync
# 14          Bespoke - Gateway Sync
# 15          Bespoke - Gateway Sync
# 16          Bespoke - Gateway Sync
# 17          Bespoke - Gateway Sync
# 18          Bespoke - Gateway Sync
# 19          Bespoke - Gateway Sync
# 20          Bespoke - Gateway Sync
# 21          Bespoke - Health Check
# 22          Bespoke - Health Check
# 23          Bespoke - Health Check
# 24          Bespoke - Health Check
# 25          Bespoke - Health Check
# 26          Bespoke - Health Check
# 27          Bespoke - Health Check
# 28          Bespoke - Health Check
# 29          Bespoke - Health Check
# ...                            ...
# 1268  Visualisation - WebDashboard
# 1269  Visualisation - WebDashboard
# 1270  Visualisation - WebDashboard
# 1271  Visualisation - WebDashboard
# 1272  Visualisation - WebDashboard
# 1273  Visualisation - WebDashboard
# 1274  Visualisation - WebDashboard
# 1275  Visualisation - WebDashboard
# 1276  Visualisation - WebDashboard
# 1277  Visualisation - WebDashboard
# 1278  Visualisation - WebDashboard
# 1279  Visualisation - WebDashboard
# 1280  Visualisation - WebDashboard
# 1281  Visualisation - WebDashboard
# 1282  Visualisation - WebDashboard
# 1283  Visualisation - WebDashboard
# 1284  Visualisation - WebDashboard
# 1285  Visualisation - WebDashboard
# 1286    Visualisation - WebMontage
# 1287    Visualisation - WebMontage
# 1288    Visualisation - WebMontage
# 1289    Visualisation - WebMontage
# 1290    Visualisation - WebMontage
# 1291    Visualisation - WebMontage
# 1292    Visualisation - WebMontage
# 1293    Visualisation - WebMontage
# 1294    Visualisation - WebMontage
# 1295    Visualisation - WebSlinger
# 1296    Visualisation - WebSlinger
# 1297    Visualisation - WebSlinger
#
#                                   title_and_description  \
# 0     ('Missing ELK Records for Gateway MSST_CRDS_NA...
# 1     ('Issue with ELK Alert Sync', 'Hi Support Team...
# 2     ('RE: Inconsistent ELK data', 'Hi Carlo,\n\nWe...
# 3     ('Prod Gateway TTS_ELK_NAM_PROD not accessible...
# 4     ('Authentication failure with new ITRS gateway...
# 5     ('GCE : Getting  ELK alerts for Zero rows', 'T...
# 6     ('GCE : Getting  ELK alerts', 'Hi Jignisha/faz...
# 7     ('ELK not collecting alerts from TTS_FLEXCUBE_...
# 8     ('Sync ITRS gateways for Trade', 'Hi ITRS Team...
# 9     ('Sync ITRS gateways for Trade ', 'Hi ITRS Tea...
# 10    ('PROD Gateway Entitlement SYNC Issues | Multi...
# 11    ('Sync ITRS gateways for channels | ', 'Hi ITR...
# 12    ('Entitlement sync issue | TTS_GPCD_GBS_STARS_...
# 13    ('entitlement issue for MSST_CRDS_NAM_PROD', '...
# 14    ('Entitlement sync for CPB_EMEA_APAC_PROD gate...
# 15    ('ITRS : Sync Issue : TTS_LMS1_NAM_PROD', 'Hi ...
# 16    ('Change the port to 7136 / 7137 so that NetPr...
# 17    ('[20181012: PENDING ENGG] Not  able to create...
# 18    ('ITRS : Sync Issue : TTS_LMS1_NAM_PROD SN# IN...
# 19    ('users not getting added during the synch', '...
# 20    ('ITRS monitoring - {ENV - PROD or COB} enviro...
# 21    ('rdcgtsncsaa01p : ITM6_K20:alert on process n...
# 22    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# 23    ('lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdic...
# 24    ('lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdic...
# 25    ('lfdicgitrdb1c : LZIOS_BP_NetMEMUSED_C: lfdic...
# 26    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# 27    ('hdcicgitvld01c : Filesystem /var free space ...
# 28    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# 29    ('lrdicgitrdb1p : LZIOS_BP_NetMEMUSED_C: lrdic...
# ...                                                 ...
# 1268  ('GHC webdashboard not working | TTS | Dashboa...
# 1269  ('Unable to load ITRS from web url', 'Hi ITRS ...
# 1270  ('Uploading XMC ETL Dashboard', 'Hi Team,\n   ...
# 1271  ("ITRS Web Dashboard - Few gateway's not worki...
# 1272  ("ITRS Web Dashboard - Few gateway's not worki...
# 1273  ('Web Dashboard Hosting | ISG_PRODUCT_NAM_PROD...
# 1274  ('Stale web dashboard not displaying correct i...
# 1275  ('Update XMC UI Dashboard', 'Hi Team,\nRaising...
# 1276  ('Upload XMC QV Dashboards', 'ITRS Web Dashboa...
# 1277  ('http://itrsswcob2:8093/ | Web dashboard URL ...
# 1278  ('WEB Dashboard BO', 'Hi Team,\n\nPlease load ...
# 1279  ("Dashboard doesn't load, please check attache...
# 1280  ('Upload XMC UI Dashboards', 'Hi Team,\nRaisin...
# 1281  ('FX Velocity: SOW ITRS Dashboard - Stale', 'I...
# 1282  ('[RCA ] Web Dashboard Unavailability Issue', ...
# 1283  ('CS - Web dashboard update', 'Please update C...
# 1284  ('Web dashboard issue - DDE | TTS | Web Dashbo...
# 1285  ('ALL - MAINT - ITRS Web dashboard issue', 'IT...
# 1286  ('Few Data views not visible on montage', "Try...
# 1287  ('COB Web montage url -None of the credentials...
# 1288  ('Web montage url -not working', 'Hi ITRS Team...
# 1289  ('**URGENT** Web montage url -not working', 'H...
# 1290  ('Web montage url -not working', 'Hi ITRS Team...
# 1291  ('web montage', "Yes we'd like it for a few of...
# 1292  ('Web montage url -not working | TTS_CRM_NAM_P...
# 1293  ('http://eqitrspsnj1.nam.nsroot.net:8181/-  We...
# 1294  ('web Montage Access', "Hi Team,\n\nOur L0 can...
# 1295  ('[20181112: ZD210049, ONGOING] URGENT - Busin...
# 1296  ('Webslinger Setup Reference', 'Hi Team,\nWe a...
# 1297  ('Webslinger and action script for Solace gate...
#
#      Combined MNB New Predicted Values  \
# 0           Netprobe - Troubleshooting
# 1           Netprobe - Troubleshooting
# 2           Netprobe - Troubleshooting
# 3           Netprobe - Troubleshooting
# 4           Netprobe - Troubleshooting
# 5           Netprobe - Troubleshooting
# 6           Netprobe - Troubleshooting
# 7           Netprobe - Troubleshooting
# 8           Netprobe - Troubleshooting
# 9           Netprobe - Troubleshooting
# 10            Gateway - Authentication
# 11            Gateway - Authentication
# 12            Gateway - Authentication
# 13          Netprobe - Troubleshooting
# 14          Netprobe - Troubleshooting
# 15          Netprobe - Troubleshooting
# 16          Netprobe - Troubleshooting
# 17          Netprobe - Troubleshooting
# 18                   Plugin - Database
# 19          Netprobe - Troubleshooting
# 20          Netprobe - Troubleshooting
# 21              Bespoke - Health Check
# 22              Bespoke - Health Check
# 23              Bespoke - Health Check
# 24              Bespoke - Health Check
# 25              Bespoke - Health Check
# 26              Bespoke - Health Check
# 27              Bespoke - Health Check
# 28              Bespoke - Health Check
# 29              Bespoke - Health Check
# ...                                ...
# 1268      Visualisation - WebDashboard
# 1269          Gateway - Authentication
# 1270      Visualisation - WebDashboard
# 1271      Visualisation - WebDashboard
# 1272      Visualisation - WebDashboard
# 1273      Visualisation - WebDashboard
# 1274      Visualisation - WebDashboard
# 1275      Visualisation - WebDashboard
# 1276      Visualisation - WebDashboard
# 1277      Visualisation - WebDashboard
# 1278      Visualisation - WebDashboard
# 1279      Visualisation - WebDashboard
# 1280      Visualisation - WebDashboard
# 1281      Visualisation - WebDashboard
# 1282        Netprobe - Troubleshooting
# 1283      Visualisation - WebDashboard
# 1284      Visualisation - WebDashboard
# 1285      Visualisation - WebDashboard
# 1286        Netprobe - Troubleshooting
# 1287        Netprobe - Troubleshooting
# 1288      Visualisation - WebDashboard
# 1289        Netprobe - Troubleshooting
# 1290        Netprobe - Troubleshooting
# 1291        Netprobe - Troubleshooting
# 1292      Visualisation - WebDashboard
# 1293        Netprobe - Troubleshooting
# 1294          Gateway - Authentication
# 1295      Visualisation - WebDashboard
# 1296        Netprobe - Troubleshooting
# 1297        Netprobe - Troubleshooting
#
#                   Combined SVC New Predicted Values  \
# 0                                     Bespoke - ELK
# 1                                     Bespoke - ELK
# 2                                     Bespoke - ELK
# 3     Gateway - Data Quality and Performance Tuning
# 4     Gateway - Data Quality and Performance Tuning
# 5                                     Bespoke - ELK
# 6                                     Bespoke - ELK
# 7                                     Bespoke - ELK
# 8                            Bespoke - Gateway Sync
# 9                            Bespoke - Gateway Sync
# 10    Gateway - Data Quality and Performance Tuning
# 11                           Bespoke - Gateway Sync
# 12                           Bespoke - Gateway Sync
# 13                           Bespoke - Gateway Sync
# 14    Gateway - Data Quality and Performance Tuning
# 15                                 Gateway - Others
# 16                           Bespoke - Gateway Sync
# 17                           Bespoke - Gateway Sync
# 18                                  Plugin - Others
# 19                           Bespoke - Gateway Sync
# 20                           Bespoke - Gateway Sync
# 21                           Bespoke - Health Check
# 22                           Bespoke - Health Check
# 23                           Bespoke - Health Check
# 24                           Bespoke - Health Check
# 25                           Bespoke - Health Check
# 26                           Bespoke - Health Check
# 27                           Bespoke - Health Check
# 28                           Bespoke - Health Check
# 29                           Bespoke - Health Check
# ...                                             ...
# 1268                   Visualisation - WebDashboard
# 1269                   Visualisation - WebDashboard
# 1270                   Visualisation - WebDashboard
# 1271                   Visualisation - WebDashboard
# 1272                   Visualisation - WebDashboard
# 1273                   Visualisation - WebDashboard
# 1274                   Visualisation - WebDashboard
# 1275                   Visualisation - WebDashboard
# 1276                   Visualisation - WebDashboard
# 1277                   Visualisation - WebDashboard
# 1278                   Visualisation - WebDashboard
# 1279                   Visualisation - WebDashboard
# 1280                   Visualisation - WebDashboard
# 1281                   Visualisation - WebDashboard
# 1282                   Visualisation - WebDashboard
# 1283                   Visualisation - WebDashboard
# 1284                   Visualisation - WebDashboard
# 1285                   Visualisation - WebDashboard
# 1286                     Visualisation - WebMontage
# 1287                     Visualisation - WebMontage
# 1288                     Visualisation - WebMontage
# 1289                     Visualisation - WebMontage
# 1290                     Visualisation - WebMontage
# 1291                     Netprobe - Troubleshooting
# 1292                     Visualisation - WebMontage
# 1293                     Visualisation - WebMontage
# 1294                     Visualisation - WebMontage
# 1295                   Visualisation - WebDashboard
# 1296                     Visualisation - WebSlinger
# 1297                     Netprobe - Troubleshooting
#
#      Title MNB New Predicted Values  \
# 0        Netprobe - Troubleshooting
# 1        Netprobe - Troubleshooting
# 2        Netprobe - Troubleshooting
# 3        Netprobe - Troubleshooting
# 4          Gateway - Authentication
# 5        Netprobe - Troubleshooting
# 6        Netprobe - Troubleshooting
# 7        Netprobe - Troubleshooting
# 8          Gateway - Authentication
# 9          Gateway - Authentication
# 10       Netprobe - Troubleshooting
# 11         Gateway - Authentication
# 12         Gateway - Authentication
# 13       Netprobe - Troubleshooting
# 14       Netprobe - Troubleshooting
# 15       Netprobe - Troubleshooting
# 16       Netprobe - Troubleshooting
# 17         Gateway - Authentication
# 18       Netprobe - Troubleshooting
# 19         Gateway - Authentication
# 20       Netprobe - Troubleshooting
# 21           Bespoke - Health Check
# 22           Bespoke - Health Check
# 23           Bespoke - Health Check
# 24           Bespoke - Health Check
# 25           Bespoke - Health Check
# 26           Bespoke - Health Check
# 27           Bespoke - Health Check
# 28           Bespoke - Health Check
# 29           Bespoke - Health Check
# ...                             ...
# 1268   Visualisation - WebDashboard
# 1269   Visualisation - WebDashboard
# 1270   Visualisation - WebDashboard
# 1271   Visualisation - WebDashboard
# 1272   Visualisation - WebDashboard
# 1273   Visualisation - WebDashboard
# 1274   Visualisation - WebDashboard
# 1275   Visualisation - WebDashboard
# 1276   Visualisation - WebDashboard
# 1277   Visualisation - WebDashboard
# 1278   Visualisation - WebDashboard
# 1279   Visualisation - WebDashboard
# 1280   Visualisation - WebDashboard
# 1281   Visualisation - WebDashboard
# 1282   Visualisation - WebDashboard
# 1283   Visualisation - WebDashboard
# 1284   Visualisation - WebDashboard
# 1285   Visualisation - WebDashboard
# 1286     Netprobe - Troubleshooting
# 1287     Netprobe - Troubleshooting
# 1288   Visualisation - WebDashboard
# 1289   Visualisation - WebDashboard
# 1290   Visualisation - WebDashboard
# 1291   Visualisation - WebDashboard
# 1292   Visualisation - WebDashboard
# 1293     Netprobe - Troubleshooting
# 1294   Visualisation - WebDashboard
# 1295   Visualisation - WebDashboard
# 1296     Netprobe - Troubleshooting
# 1297     Netprobe - Troubleshooting
#
#                      Title SVC New Predicted Values
# 0                                     Bespoke - ELK
# 1                                     Bespoke - ELK
# 2                                     Bespoke - ELK
# 3     Gateway - Data Quality and Performance Tuning
# 4                          Gateway - Authentication
# 5                                     Bespoke - ELK
# 6                                     Bespoke - ELK
# 7                                     Bespoke - ELK
# 8                            Bespoke - Gateway Sync
# 9                            Bespoke - Gateway Sync
# 10    Gateway - Data Quality and Performance Tuning
# 11                           Bespoke - Gateway Sync
# 12                           Bespoke - Gateway Sync
# 13                           Bespoke - Gateway Sync
# 14    Gateway - Data Quality and Performance Tuning
# 15                           Bespoke - Gateway Sync
# 16                           Bespoke - Gateway Sync
# 17                           Bespoke - Gateway Sync
# 18                           Bespoke - Gateway Sync
# 19                           Bespoke - Gateway Sync
# 20                                Plugin - Database
# 21                           Bespoke - Health Check
# 22                           Bespoke - Health Check
# 23                           Bespoke - Health Check
# 24                           Bespoke - Health Check
# 25                           Bespoke - Health Check
# 26                           Bespoke - Health Check
# 27                           Bespoke - Health Check
# 28                           Bespoke - Health Check
# 29                           Bespoke - Health Check
# ...                                             ...
# 1268                   Visualisation - WebDashboard
# 1269                   Visualisation - WebDashboard
# 1270                   Visualisation - WebDashboard
# 1271                   Visualisation - WebDashboard
# 1272                   Visualisation - WebDashboard
# 1273                   Visualisation - WebDashboard
# 1274                   Visualisation - WebDashboard
# 1275                   Visualisation - WebDashboard
# 1276                   Visualisation - WebDashboard
# 1277                   Visualisation - WebDashboard
# 1278                   Visualisation - WebDashboard
# 1279                   Visualisation - WebDashboard
# 1280                   Visualisation - WebDashboard
# 1281                   Visualisation - WebDashboard
# 1282                   Visualisation - WebDashboard
# 1283                   Visualisation - WebDashboard
# 1284                   Visualisation - WebDashboard
# 1285                   Visualisation - WebDashboard
# 1286                     Visualisation - WebMontage
# 1287                     Visualisation - WebMontage
# 1288                     Visualisation - WebMontage
# 1289                     Visualisation - WebMontage
# 1290                     Visualisation - WebMontage
# 1291                     Visualisation - WebMontage
# 1292                     Visualisation - WebMontage
# 1293                     Visualisation - WebMontage
# 1294                       Gateway - Authentication
# 1295                   Visualisation - WebDashboard
# 1296                     Visualisation - WebSlinger
# 1297           Plugin - API and Development Toolkit
#
# [1298 rows x 10 columns]

# %%
test_set['comparetitlesvc'] = test_set['Combined SVC New Predicted Values'] == test_set['CATEGORY']

# %%
test_set['comparetitlesvc'].value_counts(normalize=True)*100
# Out:
# True     93.836672
# False     6.163328
# Name: comparetitlesvc, dtype: float64

# %%
test_set.to_csv('sirchristiansdata_withpredictions.csv')

# %%
q1 = pd.read_csv('quarter1.csv', encoding="latin1")

# %%
q1['title_and_description'] = q1[['Title', 'Description']].apply(tuple, axis=1)

# %%
q1.to_csv('q1_withtad.csv')

# %%
q1 = pd.read_csv('q1_withtad.csv', encoding="latin1")

# %%
q1['Prediction'] = svc.predict(count_vect.transform(q1['title_and_description'].values.astype('U')))

# %%
q1
# Out:
#      Unnamed: 0         Number  \
# 0             0  INC0049062350
# 1             1  INC0049064640
# 2             2  INC0049068327
# 3             3  INC0049070427
# 4             4  INC0049073721
# 5             5  INC0049075793
# 6             6  INC0049076051
# 7             7  INC0049076525
# 8             8  INC0049077040
# 9             9  INC0049077280
# 10           10  INC0049077690
# 11           11  INC0049077836
# 12           12  INC0049078376
# 13           13  INC0049079325
# 14           14  INC0049079633
# 15           15  INC0049081487
# 16           16  INC0049082561
# 17           17  INC0049082585
# 18           18  INC0049086774
# 19           19  INC0049100450
# 20           20  INC0049106445
# 21           21  INC0049117957
# 22           22  INC0049122293
# 23           23  INC0049124258
# 24           24  INC0049130628
# 25           25  INC0049130804
# 26           26  INC0049134027
# 27           27  INC0049138424
# 28           28  INC0049138919
# 29           29  INC0049145491
# ..          ...            ...
# 796         796  INC0051366197
# 797         797  INC0051366748
# 798         798  INC0051368065
# 799         799  INC0051371936
# 800         800  INC0051373670
# 801         801  INC0051374862
# 802         802  INC0051375511
# 803         803  INC0051376860
# 804         804  INC0051379811
# 805         805  INC0051381244
# 806         806  INC0051385420
# 807         807  INC0051388960
# 808         808  INC0051389045
# 809         809  INC0051390494
# 810         810  INC0051392042
# 811         811  INC0051395392
# 812         812  INC0051396941
# 813         813  INC0051398642
# 814         814  INC0051410547
# 815         815  INC0051412305
# 816         816  INC0051414070
# 817         817  INC0051419714
# 818         818  INC0051420418
# 819         819  INC0051424998
# 820         820  INC0051428685
# 821         821  INC0051433522
# 822         822  INC0051436554
# 823         823  INC0051441775
# 824         824  INC0051442359
# 825         825  INC0051464037
#
#                                                  Title            Created  \
# 0                             Script Failure On COMET   01-Jan-2018 00:47
# 1     netprobe down | MultipleGateways | NetProbe | L2  01-Jan-2018 07:08
# 2    entities turns gray | TTS_GPRCT_EMEA_TECH_EMEA...  01-Jan-2018 15:39
# 3                Prod Reghub - Alerting to Lynch/Skype  01-Jan-2018 19:38
# 4    ManagedEntities are in Gray State and are not ...  02-Jan-2018 02:20
# 5    Unable to connect to gateway|RATES|Active Console  02-Jan-2018 06:48
# 6    Unable to connect any workspace in ITRS|EQUITI...  02-Jan-2018 07:16
# 7             ITRS not working|EQUITIES|Active Console  02-Jan-2018 08:07
# 8    TTS_GPRCT_APAC2_PROD | Gateway | L2 | Gateway ...  02-Jan-2018 08:56
# 9          Pubmonitor can not be show in ITRS web page  02-Jan-2018 09:15
# 10        TTS_GPRCT_APAC3_PROD | Gateway not available  02-Jan-2018 09:48
# 11   Not able to connect to gateway fxlmderiv_glbl_...  02-Jan-2018 10:00
# 12                                      net probe down  02-Jan-2018 10:38
# 13   ITRS Gateway issue | TTS_FLEXCUBE_APAC_PROD | ...  02-Jan-2018 11:26
# 14   PROD ITRS URL is having some issues | Equities...  02-Jan-2018 11:49
# 15                                   ITRS access issue  02-Jan-2018 13:45
# 16   Reghub - Restricting netprob  from running as ...  02-Jan-2018 14:46
# 17   ITRS RED :  COB : GBNP : ITRS-LOG | TTS_LMS1_N...  02-Jan-2018 14:47
# 18                         Process Plugin Auto-Restart  02-Jan-2018 18:12
# 19   Exception occurred while starting up, forcing ...  03-Jan-2018 03:38
# 20   Please help to check the below error in ITRS|T...  03-Jan-2018 09:39
# 21   RE: False alerting in ITRS | qioi_geotrdr_nam_...  03-Jan-2018 20:39
# 22   [PENDING CONFIRMATION] gateway not available -...  03-Jan-2018 23:42
# 23   L2  netprobe restart command not working from ...  04-Jan-2018 00:59
# 24   webslinger for exec_nam_us_prod gateway | exec...  04-Jan-2018 06:16
# 25   EMEA netprobes | eqrisk_emea_gb_prod | NetProb...  04-Jan-2018 06:27
# 26       use ITRS to start/stop process in unxi system  04-Jan-2018 10:24
# 27   RE: Prog Reghub - Process not getting restarte...  04-Jan-2018 15:06
# 28   Today alert for this entity "KR Trading Engine...  04-Jan-2018 15:33
# 29                       Disable Unreachable Netprobes  04-Jan-2018 20:40
# ..                                                 ...                ...
# 796  Script failure on ZTS TK - eqmohkprod, Copy of...  27-Mar-2018 20:03
# 797  I am from Citi Lifecycle project(Appid 171298)...  27-Mar-2018 20:28
# 798  ITRS Sampling Error | cmot_xm_global_ww_prod |...  27-Mar-2018 21:22
# 799  ITRS monitoring - {ENV - PROD or COB} environm...  27-Mar-2018 23:33
# 800  CitiFT Sampling status error for all three reg...  28-Mar-2018 00:30
# 801  ITRS Access | icg_emea_bigdata_gds_uk_prod | A...  28-Mar-2018 01:18
# 802  ITRS warning alerts being reported as critical...  28-Mar-2018 01:46
# 803              netprob showing down-- rdcctslnaad03p  28-Mar-2018 02:48
# 804                                 ITRS Web Dashboard  28-Mar-2018 04:49
# 805   Sampling Status Fail | cmot_refer_global_ww_p...  28-Mar-2018 06:07
# 806  [NETPROBE UPGRADE] Probe Crashing | TTS_IMASS_...  28-Mar-2018 11:20
# 807  ITRS Web dashboard not refreshing | MultipleGa...  28-Mar-2018 14:13
# 808                 Raised INC for getting WAIS tokens  28-Mar-2018 14:17
# 809  Restart web server of http://hdcicgitvld04c:94...  28-Mar-2018 15:33
# 810  E-COPY - ITRS installation on CPBMWDMSPE1 & CP...  28-Mar-2018 16:46
# 811           I want to create a gateway for itrs node  28-Mar-2018 19:26
# 812  Netprobe on uk1pcrio01.prod.lava:7137 went dow...  28-Mar-2018 20:40
# 813  ITRS issue | TTS_FLEXCUBE_EMEA_PROD | Gateway ...  28-Mar-2018 21:50
# 814  ITRS RED -- KOFAX -- WIN USERS --- | TTS_TRADE...  29-Mar-2018 06:39
# 815  Netprobe down on EQTTANNAAPPR01 | deriv_nam_us...  29-Mar-2018 09:05
# 816  Issue with gateway : lnjicgitrap1p.nam.nsroot....  29-Mar-2018 11:09
# 817                                     ITRS Dashboard  29-Mar-2018 16:12
# 818                            Web URL is not working   29-Mar-2018 16:48
# 819  Snooze access for below MANAGED ENTITY NAME in...  29-Mar-2018 20:41
# 820  eqitrs2c : Net Memory Used high Last 15 mins: ...  29-Mar-2018 23:11
# 821  GBS/GBSX/MIFT:  Unable to connect to 3DNS in I...  30-Mar-2018 03:07
# 822  ICG Unix Core Support -  Break/Fix | Credit_NY...  30-Mar-2018 06:23
# 823           gateways access | Equities | Access | L2  30-Mar-2018 13:22
# 824           Alert on instanceCount not matching rule  30-Mar-2018 14:07
# 825  lrdicgitrap1p : Filesystem /var free space is ...  31-Mar-2018 15:55
#
#                   Assignee Incident state            Updated Updated by  \
# 0          Rodolfo Villosa         Closed  04-Jan-2018 08:03     system
# 1             Carlo Pasaol         Closed  04-Jan-2018 23:08     system
# 2             Carlo Pasaol         Closed  04-Jan-2018 23:06     system
# 3             Carlo Pasaol         Closed  01-Jan-2018 21:41    CP75703
# 4             Carlo Pasaol         Closed  05-Jan-2018 05:04     system
# 5          Christian Palma         Closed  16-Jan-2018 15:20     system
# 6          Christian Palma         Closed  16-Jan-2018 15:19     system
# 7          Christian Palma         Closed  16-Jan-2018 15:16     system
# 8          Christian Palma         Closed  07-Jan-2018 13:42     system
# 9          Christian Palma         Closed  08-Jan-2018 06:56     system
# 10         Christian Palma         Closed  07-Jan-2018 11:41     system
# 11         Christian Palma         Closed  07-Jan-2018 11:41     system
# 12         Christian Palma         Closed  07-Jan-2018 11:44     system
# 13       Angeli Panganiban         Closed  07-Jan-2018 11:45     system
# 14       Angeli Panganiban         Closed  05-Jan-2018 12:15     system
# 15   Jesse Alueta Jadraque         Closed  07-Jan-2018 14:07     system
# 16   Jesse Alueta Jadraque         Closed  02-Jan-2018 16:27    JJ00463
# 17            Carlo Pasaol         Closed  07-Jan-2018 06:07     system
# 18   Jesse Alueta Jadraque         Closed  15-Jan-2018 21:57     system
# 19       Liberty Anne Sayo         Closed  06-Jan-2018 05:14     system
# 20         Christian Palma         Closed  17-Feb-2018 12:09     system
# 21        Sesenado Ordonez         Closed  14-Jan-2018 18:29     system
# 22            Carlo Pasaol         Closed  06-Mar-2018 15:44     system
# 23       Liberty Anne Sayo         Closed  09-Jan-2018 03:36     system
# 24       Angeli Panganiban         Closed  04-Jan-2018 09:53    AP96306
# 25        Benjamin Mendoza         Closed  09-Jan-2018 07:58     system
# 26       Angeli Panganiban         Closed  04-Jan-2018 10:39    AP96306
# 27        Sesenado Ordonez         Closed  28-Feb-2018 09:11     system
# 28         Christian Palma         Closed  04-Jan-2018 16:05    CP96308
# 29        Sesenado Ordonez         Closed  04-Jan-2018 21:17    SO19147
# ..                     ...            ...                ...        ...
# 796           Carlo Pasaol         Closed  02-Apr-2018 11:25     system
# 797  Christian Angel Reyes         Closed  05-Apr-2018 03:14    CR86441
# 798  Concepcion Prosperoso         Closed  30-Mar-2018 22:28     system
# 799        Rodolfo Villosa         Closed  31-Mar-2018 04:09     system
# 800           Carlo Pasaol         Closed  04-Apr-2018 09:04     system
# 801        Rodolfo Villosa         Closed  28-Mar-2018 04:16    RV75698
# 802        Rodolfo Villosa         Closed  08-Apr-2018 00:26     system
# 803        Rodolfo Villosa         Closed  07-Apr-2018 10:08     system
# 804        Rodolfo Villosa         Closed  28-Mar-2018 04:58    RV75698
# 805           Carlo Pasaol         Closed  31-Mar-2018 11:04     system
# 806           Carlo Pasaol         Closed  31-Mar-2018 14:03     system
# 807  Concepcion Prosperoso         Closed  06-Aug-2018 15:04    UC59675
# 808           Carlo Pasaol         Closed  01-Apr-2018 11:06     system
# 809  Concepcion Prosperoso         Closed  31-Mar-2018 20:00     system
# 810      Angeli Panganiban         Closed  31-Mar-2018 20:12     system
# 811       Sesenado Ordonez         Closed  03-Apr-2018 07:12     system
# 812      Angeli Panganiban         Closed  02-Apr-2018 21:48     system
# 813  Concepcion Prosperoso         Closed  31-Mar-2018 23:12     system
# 814           Carlo Pasaol         Closed  01-Apr-2018 09:15     system
# 815           Carlo Pasaol         Closed  01-Apr-2018 13:20     system
# 816           Carlo Pasaol         Closed  01-Apr-2018 12:10     system
# 817  Concepcion Prosperoso         Closed  01-Apr-2018 18:19     system
# 818  Concepcion Prosperoso         Closed  01-Apr-2018 22:01     system
# 819  Concepcion Prosperoso         Closed  05-Apr-2018 09:33     system
# 820  Concepcion Prosperoso         Closed  04-Apr-2018 09:21     system
# 821        Rodolfo Villosa         Closed  15-Apr-2018 08:40     system
# 822           Carlo Pasaol         Closed  02-Apr-2018 10:15     system
# 823           Carlo Pasaol         Closed  30-Mar-2018 13:27    CP75703
# 824            Daryl Rojas         Closed  08-Apr-2018 12:15     system
# 825            Daryl Rojas         Closed  13-Apr-2018 10:03     system
#
#          Priority             Closed            Resolved by  \
# 0      3 - Medium  04-Jan-2018 08:03        Rodolfo Villosa
# 1      3 - Medium  04-Jan-2018 23:08           Carlo Pasaol
# 2      3 - Medium  04-Jan-2018 23:06           Carlo Pasaol
# 3      3 - Medium  01-Jan-2018 21:41           Carlo Pasaol
# 4        2 - High  05-Jan-2018 05:04           Carlo Pasaol
# 5        2 - High  16-Jan-2018 15:20        Christian Palma
# 6      3 - Medium  16-Jan-2018 15:19        Christian Palma
# 7    1 - Critical  16-Jan-2018 15:16        Christian Palma
# 8        2 - High  07-Jan-2018 13:42                    NaN
# 9      3 - Medium  08-Jan-2018 06:56                    NaN
# 10       2 - High  07-Jan-2018 11:41                    NaN
# 11       2 - High  07-Jan-2018 11:41                    NaN
# 12     3 - Medium  07-Jan-2018 11:44                    NaN
# 13        4 - Low  07-Jan-2018 11:45                    NaN
# 14       2 - High  05-Jan-2018 12:15      Angeli Panganiban
# 15        4 - Low  07-Jan-2018 14:07                    NaN
# 16       2 - High  02-Jan-2018 16:27  Jesse Alueta Jadraque
# 17        4 - Low  07-Jan-2018 06:07           Carlo Pasaol
# 18     3 - Medium  15-Jan-2018 21:57                    NaN
# 19        4 - Low  06-Jan-2018 05:14      Liberty Anne Sayo
# 20     3 - Medium  17-Feb-2018 12:09        Christian Palma
# 21     3 - Medium  14-Jan-2018 18:29       Sesenado Ordonez
# 22       2 - High  06-Mar-2018 15:44                    NaN
# 23        4 - Low  09-Jan-2018 03:36                    NaN
# 24       2 - High  04-Jan-2018 09:53      Angeli Panganiban
# 25     3 - Medium  09-Jan-2018 07:58                    NaN
# 26       2 - High  04-Jan-2018 10:39      Angeli Panganiban
# 27     3 - Medium  28-Feb-2018 09:11                    NaN
# 28       2 - High  04-Jan-2018 16:05        Christian Palma
# 29     3 - Medium  04-Jan-2018 21:17       Sesenado Ordonez
# ..            ...                ...                    ...
# 796    3 - Medium  02-Apr-2018 11:25                    NaN
# 797    3 - Medium  05-Apr-2018 03:14  Christian Angel Reyes
# 798    3 - Medium  30-Mar-2018 22:28  Concepcion Prosperoso
# 799      2 - High  31-Mar-2018 04:09        Rodolfo Villosa
# 800      2 - High  04-Apr-2018 09:04                    NaN
# 801    3 - Medium  28-Mar-2018 04:16        Rodolfo Villosa
# 802       4 - Low  08-Apr-2018 00:26        Rodolfo Villosa
# 803      2 - High  07-Apr-2018 10:08      Angeli Panganiban
# 804      2 - High  28-Mar-2018 04:58        Rodolfo Villosa
# 805      2 - High  31-Mar-2018 11:04           Carlo Pasaol
# 806    3 - Medium  31-Mar-2018 14:03           Carlo Pasaol
# 807      2 - High  31-Mar-2018 19:24  Concepcion Prosperoso
# 808       4 - Low  01-Apr-2018 11:06           Carlo Pasaol
# 809       4 - Low  31-Mar-2018 20:00  Concepcion Prosperoso
# 810    3 - Medium  31-Mar-2018 20:12      Angeli Panganiban
# 811       4 - Low  03-Apr-2018 07:12                    NaN
# 812    3 - Medium  02-Apr-2018 21:48                    NaN
# 813      2 - High  31-Mar-2018 23:12  Concepcion Prosperoso
# 814       4 - Low  01-Apr-2018 09:15           Carlo Pasaol
# 815    3 - Medium  01-Apr-2018 13:20           Carlo Pasaol
# 816      2 - High  01-Apr-2018 12:10           Carlo Pasaol
# 817    3 - Medium  01-Apr-2018 18:19  Concepcion Prosperoso
# 818      2 - High  01-Apr-2018 22:01  Concepcion Prosperoso
# 819    3 - Medium  05-Apr-2018 09:33  Concepcion Prosperoso
# 820      2 - High  04-Apr-2018 09:21      Angeli Panganiban
# 821    3 - Medium  15-Apr-2018 08:40                    NaN
# 822    3 - Medium  02-Apr-2018 10:15           Carlo Pasaol
# 823    3 - Medium  30-Mar-2018 13:27           Carlo Pasaol
# 824    3 - Medium  08-Apr-2018 12:15      Angeli Panganiban
# 825      2 - High  13-Apr-2018 10:03       Benjamin Mendoza
#
#               Resolved                                        Description  \
# 0    01-Jan-2018 07:12  Hi Team ,\r\n\r\nWe could see script failure o...
# 1    01-Jan-2018 22:57  Please start the following down and unreachabl...
# 2    01-Jan-2018 22:17  Please check below entities turns gray (not co...
# 3    01-Jan-2018 21:41  Hi Arman / ITRS team \r\nIs there any action s...
# 4    02-Jan-2018 04:51  Norclear DK1 Incoming files and Norclear DK1  ...
# 5    13-Jan-2018 14:30  ITRS Support,\r\nI am unable to connect to rat...
# 6    13-Jan-2018 14:17  Hi Team,\r\nWe are not able to connect any of ...
# 7    13-Jan-2018 14:28  Hi ITRS Team,\r\n\r\nCan someone urgently help...
# 8    07-Jan-2018 13:42  Hi,\r\nPlease help to check TTS_GPRCT_APAC2_PR...
# 9    08-Jan-2018 06:56  Hi ITRS Team\r\n\r\nThe Publication Monitor Pa...
# 10   07-Jan-2018 11:41  TTS_GPRCT_APAC3_PROD | Gateway not available\r...
# 11   07-Jan-2018 11:41  We are not able to connect to our gateway fxlm...
# 12   07-Jan-2018 11:44  Hi Team , \r\n\r\nWe could see below net probe...
# 13   07-Jan-2018 11:45  Hello Team,\r\n\r\nWe now are able to see mutl...
# 14   02-Jan-2018 12:05  Hi Team,\r\n\r\nCould you please assist here. ...
# 15   07-Jan-2018 14:07  Hi Team,\r\n\r\nWhen I login to ITRS, my id tr...
# 16   02-Jan-2018 16:27  Hi ITRS team \r\nWhy is a netprobe restricted ...
# 17   04-Jan-2018 05:04  Hi ITRS Team,\r\n\r\nWe do not have any restar...
# 18   15-Jan-2018 21:57  This ticket is to track issue encountered by S...
# 19   03-Jan-2018 04:38  Hi,\r\n\r\nI'm trying to use ITRS Geneos Activ...
# 20   14-Feb-2018 11:03  Hi Team,\r\n\r\nPlease help to check the below...
# 21   11-Jan-2018 17:41  Hi ITRS Team,\r\n\r\nCould you please check wh...
# 22   06-Mar-2018 15:44  fxlm_at3_emea_uk_prod gateway is showing all p...
# 23   09-Jan-2018 03:36  When trying to use L2 commands in Active Geneo...
# 24   04-Jan-2018 09:53  Could you please advise if we have a webslinge...
# 25   09-Jan-2018 07:58  Hi Team\r\n\r\nCould you please check on the s...
# 26   04-Jan-2018 10:39  Hi Team,\r\n\r\nNeed some guide to use ITRS to...
# 27   28-Feb-2018 09:11  Hi Jesse\r\nAny updates on the investigation? ...
# 28   04-Jan-2018 16:05  Please provide the todays(4-jan-2017) alerts f...
# 29   04-Jan-2018 21:17  Hi Team,\r\n\r\nPlease disable the below liste...
# ..                 ...                                                ...
# 796  02-Apr-2018 11:25  Entity:                     ZTS TK - eqmohkpro...
# 797  05-Apr-2018 03:14  I am from Citi Lifecycle project(Appid 171298)...
# 798  27-Mar-2018 21:50  Hi ITRS Team,\r\n\r\nCould you please urgently...
# 799  28-Mar-2018 03:09  Hi ITRS Support team,\r\n\r\nCan you please le...
# 800  04-Apr-2018 09:04        Script completed with errors. See log file.
# 801  28-Mar-2018 04:16  Please provide access to ITRS Gateway: icg_eme...
# 802  04-Apr-2018 23:47  ITRS engineering team,\r\n\r\nIt looks like on...
# 803  04-Apr-2018 09:36  Hi Team,\r\n\r\nnetprobs are showing down in I...
# 804  28-Mar-2018 04:58  Need to create a web dashboard for the attache...
# 805  28-Mar-2018 10:33  Gateway: cmot_refer_global_ww_prod\r\nEntity: ...
# 806  28-Mar-2018 13:16  Server: SDCICGPASLD01P\r\nPort: 7890\r\n\r\n\r...
# 807  28-Mar-2018 19:05  ITRS WEB dashboard is not refresing . Please c...
# 808  29-Mar-2018 10:26                 Raised INC for getting WAIS tokens
# 809  28-Mar-2018 19:11  Restart web server of http://hdcicgitvld04c:94...
# 810  28-Mar-2018 19:42  Hi ITRS Team ,\r\n\r\nCould you please let us ...
# 811  03-Apr-2018 07:12  User Problem Statement:I want to create a gate...
# 812  02-Apr-2018 21:48  Hi Team,\r\n\r\nThe netprobe uk1pcrio01.prod.l...
# 813  28-Mar-2018 22:32  We have faced the issue while accessing editin...
# 814  29-Mar-2018 08:15  We have got the netprobe restarted.Alert is ag...
# 815  29-Mar-2018 13:01  ERROR: NP More than 10 core files with the sam...
# 816  29-Mar-2018 11:13  We are unable to connect below gateway. Please...
# 817  29-Mar-2018 17:27  Hi Team,\r\n\r\nI have upload below on dashboa...
# 818  29-Mar-2018 21:05  Hi ITRS Team, \r\n\r\nBelow URL is not working...
# 819  02-Apr-2018 08:25  Dear ITRS Support Team,\r\n\r\nLast week we ha...
# 820  01-Apr-2018 08:34  eqitrs2c : Critical : ITM6 : LZIOS_BP_NetMEMUS...
# 821  15-Apr-2018 08:40  ITRS team,\r\nCan you please review and advise...
# 822  30-Mar-2018 10:09  Why are we getting these alerts when we have a...
# 823  30-Mar-2018 13:27  Please revoke write access on below gateways f...
# 824  05-Apr-2018 11:43  Hi Team,\r\n\r\nPlease help check why the foll...
# 825  10-Apr-2018 09:08  Full title: lrdicgitrap1p : Filesystem /var fr...
#
#                                  title_and_description  \
# 0    ('Script Failure On COMET ', "Hi Team ,\n\nWe ...
# 1    ('netprobe down | MultipleGateways | NetProbe ...
# 2    ('entities turns gray | TTS_GPRCT_EMEA_TECH_EM...
# 3    ('Prod Reghub - Alerting to Lynch/Skype', 'Hi ...
# 4    ('ManagedEntities are in Gray State and are no...
# 5    ('Unable to connect to gateway|RATES|Active Co...
# 6    ('Unable to connect any workspace in ITRS|EQUI...
# 7    ('ITRS not working|EQUITIES|Active Console', "...
# 8    ('TTS_GPRCT_APAC2_PROD | Gateway | L2 | Gatewa...
# 9    ('Pubmonitor can not be show in ITRS web page'...
# 10   ('TTS_GPRCT_APAC3_PROD | Gateway not available...
# 11   ('Not able to connect to gateway fxlmderiv_glb...
# 12   (' net probe down', 'Hi Team , \n\nWe could se...
# 13   ('ITRS Gateway issue | TTS_FLEXCUBE_APAC_PROD ...
# 14   ('PROD ITRS URL is having some issues | Equiti...
# 15   ('ITRS access issue', "Hi Team,\n\nWhen I logi...
# 16   ('Reghub - Restricting netprob  from running a...
# 17   ('ITRS RED :  COB : GBNP : ITRS-LOG | TTS_LMS1...
# 18   ('Process Plugin Auto-Restart', 'This ticket i...
# 19   ('Exception occurred while starting up, forcin...
# 20   ('Please help to check the below error in ITRS...
# 21   ('RE: False alerting in ITRS | qioi_geotrdr_na...
# 22   ('[PENDING CONFIRMATION] gateway not available...
# 23   ('L2  netprobe restart command not working fro...
# 24   ('webslinger for exec_nam_us_prod gateway | ex...
# 25   ('EMEA netprobes | eqrisk_emea_gb_prod | NetPr...
# 26   ('use ITRS to start/stop process in unxi syste...
# 27   ('RE: Prog Reghub - Process not getting restar...
# 28   ('Today alert for this entity "KR Trading Engi...
# 29   ('Disable Unreachable Netprobes', 'Hi Team,\n\...
# ..                                                 ...
# 796  ('Script failure on ZTS TK - eqmohkprod, Copy ...
# 797  ('I am from Citi Lifecycle project(Appid 17129...
# 798  ('ITRS Sampling Error | cmot_xm_global_ww_prod...
# 799  ('ITRS monitoring - {ENV - PROD or COB} enviro...
# 800  ('CitiFT Sampling status error for all three r...
# 801  ('ITRS Access | icg_emea_bigdata_gds_uk_prod |...
# 802  ('ITRS warning alerts being reported as critic...
# 803  ('netprob showing down-- rdcctslnaad03p', 'Hi ...
# 804  ('ITRS Web Dashboard', "Need to create a web d...
# 805  (' Sampling Status Fail | cmot_refer_global_ww...
# 806  ('[NETPROBE UPGRADE] Probe Crashing | TTS_IMAS...
# 807  ('ITRS Web dashboard not refreshing | Multiple...
# 808  ('Raised INC for getting WAIS tokens', 'Raised...
# 809  ('Restart web server of http://hdcicgitvld04c:...
# 810  ('E-COPY - ITRS installation on CPBMWDMSPE1 & ...
# 811  ('I want to create a gateway for itrs node', '...
# 812  ('Netprobe on uk1pcrio01.prod.lava:7137 went d...
# 813  ('ITRS issue | TTS_FLEXCUBE_EMEA_PROD | Gatewa...
# 814  ('ITRS RED -- KOFAX -- WIN USERS --- | TTS_TRA...
# 815  ('Netprobe down on EQTTANNAAPPR01 | deriv_nam_...
# 816  ('Issue with gateway : lnjicgitrap1p.nam.nsroo...
# 817  ('ITRS Dashboard', 'Hi Team,\n\nI have upload ...
# 818  ('Web URL is not working ', 'Hi ITRS Team, \n\...
# 819  ('Snooze access for below MANAGED ENTITY NAME ...
# 820  ('eqitrs2c : Net Memory Used high Last 15 mins...
# 821  ('GBS/GBSX/MIFT:  Unable to connect to 3DNS in...
# 822  ('ICG Unix Core Support -  Break/Fix | Credit_...
# 823  ('gateways access | Equities | Access | L2', '...
# 824  ('Alert on instanceCount not matching rule', '...
# 825  ('lrdicgitrap1p : Filesystem /var free space i...
#
#                                         Prediction
# 0                                Plugin - Database
# 1                       Netprobe - Troubleshooting
# 2    Gateway - Data Quality and Performance Tuning
# 3                         Gateway - Authentication
# 4                       Netprobe - Troubleshooting
# 5                         Gateway - Authentication
# 6                         Gateway - Authentication
# 7                         Gateway - Authentication
# 8    Gateway - Data Quality and Performance Tuning
# 9                     Visualisation - WebDashboard
# 10   Gateway - Data Quality and Performance Tuning
# 11   Gateway - Data Quality and Performance Tuning
# 12                      Netprobe - Troubleshooting
# 13   Gateway - Data Quality and Performance Tuning
# 14                      Netprobe - Troubleshooting
# 15                        Gateway - Authentication
# 16                      Netprobe - Troubleshooting
# 17             Gateway - Rules, Actions and Alerts
# 18   Gateway - Data Quality and Performance Tuning
# 19                        Gateway - Authentication
# 20                    Visualisation - WebDashboard
# 21                             Plugin - Middleware
# 22   Gateway - Data Quality and Performance Tuning
# 23                      Netprobe - Troubleshooting
# 24   Gateway - Data Quality and Performance Tuning
# 25                      Netprobe - Troubleshooting
# 26                        Gateway - Authentication
# 27             Gateway - Rules, Actions and Alerts
# 28            Plugin - API and Development Toolkit
# 29                      Netprobe - Troubleshooting
# ..                                             ...
# 796                              Plugin - Database
# 797                         Gateway - Installation
# 798                              Plugin - Database
# 799  Gateway - Data Quality and Performance Tuning
# 800           Plugin - API and Development Toolkit
# 801                       Gateway - Authentication
# 802  Gateway - Data Quality and Performance Tuning
# 803                     Netprobe - Troubleshooting
# 804                   Visualisation - WebDashboard
# 805           Plugin - API and Development Toolkit
# 806                     Netprobe - Troubleshooting
# 807                   Visualisation - WebDashboard
# 808                   Bespoke - Technology Toolbar
# 809                   Visualisation - WebDashboard
# 810  Gateway - Data Quality and Performance Tuning
# 811                         Gateway - Installation
# 812                     Netprobe - Troubleshooting
# 813  Gateway - Data Quality and Performance Tuning
# 814                              Plugin - Database
# 815                     Netprobe - Troubleshooting
# 816  Gateway - Data Quality and Performance Tuning
# 817                   Visualisation - WebDashboard
# 818                   Visualisation - WebDashboard
# 819                             Gateway - Commands
# 820           Plugin - API and Development Toolkit
# 821                       Plugin - File Monitoring
# 822                       Plugin - File Monitoring
# 823                       Gateway - Authentication
# 824            Gateway - Rules, Actions and Alerts
# 825                         Bespoke - Health Check
#
# [826 rows x 15 columns]

# %%
q1.groupby('Prediction').title_and_description.count().plot.bar(ylim=0)
plt.show()

# %%
ts = pd.read_csv('new_sirchristians.csv', encoding="latin1")

# %%
ts['title_and_description'] = ts[['Title', 'Description']].apply(tuple, axis=1)

# %%
ts.to_csv('new_sirchristianswtad.csv')

# %%
ts = pd.read_csv('new_sirchristianswtad.csv', encoding="latin1")

# %%
ts['Predicted'] = svc.predict(count_vect.transform(ts['title_and_description'].values.astype('U')))

# %%
ts
# Out:
#      Unnamed: 0         Number  \
# 0             0  INC0049077280
# 1             1  INC0049081487
# 2             2  INC0049217964
# 3             3  INC0049218530
# 4             4  INC0049285561
# 5             5  INC0049285638
# 6             6  INC0049287551
# 7             7  INC0049381535
# 8             8  INC0049420286
# 9             9  INC0049455133
# 10           10  INC0049495854
# 11           11  INC0049534210
# 12           12  INC0049559001
# 13           13  INC0049744902
# 14           14  INC0049780175
# 15           15  INC0049814510
# 16           16  INC0049870487
# 17           17  INC0049883495
# 18           18  INC0049917048
# 19           19  INC0049994444
# 20           20  INC0050035412
# 21           21  INC0050059416
# 22           22  INC0050125957
# 23           23  INC0050126763
# 24           24  INC0050140517
# 25           25  INC0050156066
# 26           26  INC0050160112
# 27           27  INC0050171168
# 28           28  INC0050271014
# 29           29  INC0050282955
# ..          ...            ...
# 244         244  INC0051199970
# 245         245  INC0051203969
# 246         246  INC0051226712
# 247         247  INC0051253764
# 248         248  INC0051264538
# 249         249  INC0051282602
# 250         250  INC0051299266
# 251         251  INC0051307944
# 252         252  INC0051308722
# 253         253  INC0051316732
# 254         254  INC0051317685
# 255         255  INC0051318597
# 256         256  INC0051319444
# 257         257  INC0051331192
# 258         258  INC0051345365
# 259         259  INC0051352480
# 260         260  INC0051353694
# 261         261  INC0051353866
# 262         262  INC0051373670
# 263         263  INC0051374862
# 264         264  INC0051379811
# 265         265  INC0051381244
# 266         266  INC0051388960
# 267         267  INC0051390494
# 268         268  INC0051419714
# 269         269  INC0051420418
# 270         270  INC0051424998
# 271         271  INC0051428685
# 272         272  INC0051441775
# 273         273  INC0051464037
#
#                                                  Title          Created  \
# 0          Pubmonitor can not be show in ITRS web page    1/2/2018 9:15
# 1                                    ITRS access issue   1/2/2018 13:45
# 2    RE: Sampling status failed.  || INC0049217223 ...   1/8/2018 13:24
# 3    Sampling status alert on Hardware - myeqtm1c-t...   1/8/2018 13:49
# 4    [PENDING CONFIRMATION] Gateway - Service now s...  1/10/2018 21:31
# 5     RE: Script failure alert on  EPS access output    1/10/2018 21:35
# 6    ITRS is not working | TTS_GPRCT_EMEA_TECH_EMEA...  1/10/2018 22:51
# 7    Please enable the gateways | MultipleGateways ...  1/14/2018 21:13
# 8    diskProfile Alert -| fxlmderiv_glbl_ww_prod| H...  1/16/2018 17:33
# 9    McShield (anti-virus ÃÂ"mcshield.exe") was c...  1/17/2018 22:21
# 10   FID expiry alert | TTS_LMS_NAM_PROD | SQL Toolkit  1/19/2018 10:06
# 11   Please Disable the gateways | MultipleGateways...   1/21/2018 0:43
# 12   Alerts in EMS | platems2_nam_us_prod | E4JMS | L2   1/22/2018 6:17
# 13   153106 : icgrecon02-vip1-ops : BATCH INST PA4 ...  1/29/2018 14:32
# 14   FAIL [Script returned no output] error - ITRS ...  1/30/2018 17:37
# 15           User Query | MSST_RPA_NAM_PROD | FKM | L2  1/31/2018 21:12
# 16                             FKM Instance Count Rule   2/2/2018 16:13
# 17                                ITRS missed Alerting    2/3/2018 1:13
# 18   Fail - ct_connect(): network packet layer: int...   2/4/2018 10:53
# 19   ITRS Log file for the script error | fxlmbo_gl...    2/7/2018 5:54
# 20   [PENDING CONFIRMATION] Can't accept errors | M...   2/8/2018 15:33
# 21   Kindly advise on Unsnooze logic on filesystem ...   2/9/2018 10:45
# 22                                       Alerts in EMS   2/12/2018 3:43
# 23          ****Sampler script not found wxception****   2/12/2018 5:24
# 24    Script failure alert on  RV Ticks All Risk EQ...  2/12/2018 19:13
# 25   Reason: Missing JAR file: java.util.concurrent...   2/13/2018 5:38
# 26               TTS_GPRCT_APAC1_PROD SN Group Mapping   2/13/2018 9:41
# 27    config access has not been granted|TTS|Config|L2  2/13/2018 17:47
# 28   eqitrs2c : Total System Swap free percentage l...   2/17/2018 8:27
# 29   All the gateways configured are getting grayed...  2/17/2018 22:10
# ..                                                 ...              ...
# 244  Multiple script failures in EMEA CASH | cobra_...  3/21/2018 20:44
# 245  eqitrs2c : Net Memory Used high Last 15 mins: ...  3/21/2018 22:55
# 246  rdcistitvld02p : Net Memory Used high Last 15 ...  3/22/2018 18:26
# 247  RE: CITI FPP - ITRS & Service Now Group | TTS_...  3/23/2018 15:47
# 248  Snooze option disabled for all our L1 and L2 T...   3/24/2018 0:04
# 249                                     Gateway access  3/24/2018 16:39
# 250  Sampling Status Fail | cmot_otms_nam_us_prod |...   3/25/2018 9:04
# 251  rdcistitvld02p : Net Memory Used high Last 15 ...  3/25/2018 16:16
# 252  swdctinasf7005a : Volume /vol/swdcerv0006 is n...  3/25/2018 17:01
# 253  rdcistitvld02p : Net Memory Used high Last 15 ...   3/26/2018 2:15
# 254  rdcistitvld02p : Total System Swap free percen...   3/26/2018 4:22
# 255  rdcistitvld02p : Total System Swap free percen...   3/26/2018 6:19
# 256  rdcistitvld02p : Total System Swap free percen...   3/26/2018 7:39
# 257                       ITRS access to accept alerts  3/26/2018 17:58
# 258  Provide Write Access to ITRS Gateway | Equitie...   3/27/2018 2:34
# 259  ITRS Monitoring - mounts | moff_apac_hk_prod_g...   3/27/2018 9:03
# 260  ITRS GATEWAY ACCESS | TTS_TIBCO_NAM_PROD | Acc...  3/27/2018 10:26
# 261  FW: Prod ITRS Regional Initiative - Read-only ...  3/27/2018 10:40
# 262  CitiFT Sampling status error for all three reg...   3/28/2018 0:30
# 263  ITRS Access | icg_emea_bigdata_gds_uk_prod | A...   3/28/2018 1:18
# 264                                 ITRS Web Dashboard   3/28/2018 4:49
# 265   Sampling Status Fail | cmot_refer_global_ww_p...   3/28/2018 6:07
# 266  ITRS Web dashboard not refreshing | MultipleGa...  3/28/2018 14:13
# 267  Restart web server of http://hdcicgitvld04c:94...  3/28/2018 15:33
# 268                                     ITRS Dashboard  3/29/2018 16:12
# 269                            Web URL is not working   3/29/2018 16:48
# 270  Snooze access for below MANAGED ENTITY NAME in...  3/29/2018 20:41
# 271  eqitrs2c : Net Memory Used high Last 15 mins: ...  3/29/2018 23:11
# 272           gateways access | Equities | Access | L2  3/30/2018 13:22
# 273  lrdicgitrap1p : Filesystem /var free space is ...  3/31/2018 15:55
#
#                   Assignee Incident state          Updated Updated by  \
# 0          Christian Palma         Closed    1/8/2018 6:56     system
# 1    Jesse Alueta Jadraque         Closed   1/7/2018 14:07     system
# 2        Angeli Panganiban         Closed  1/11/2018 16:11     system
# 3    Jesse Alueta Jadraque         Closed  1/11/2018 16:13     system
# 4             Carlo Pasaol         Closed   3/6/2018 15:30     system
# 5          Rodolfo Villosa         Closed  1/13/2018 23:07     system
# 6             Carlo Pasaol         Closed    2/2/2018 8:29     system
# 7             Carlo Pasaol         Closed  1/17/2018 23:14     system
# 8         Sesenado Ordonez         Closed   2/18/2018 9:16     system
# 9             Carlo Pasaol         Closed  1/20/2018 23:22     system
# 10         Christian Palma         Closed  1/24/2018 10:26     system
# 11            Carlo Pasaol         Closed   1/24/2018 2:03     system
# 12       Angeli Panganiban         Closed   1/25/2018 8:14     system
# 13   Jesse Alueta Jadraque         Closed   2/2/2018 10:36    JJ00463
# 14         Rodolfo Villosa         Closed   2/2/2018 22:15     system
# 15            Carlo Pasaol         Closed  3/22/2018 18:27     system
# 16        Sesenado Ordonez         Closed  2/13/2018 12:20     system
# 17   Christian Angel Reyes         Closed  2/21/2018 18:18     system
# 18         Rodolfo Villosa         Closed   2/7/2018 12:18     system
# 19         Rodolfo Villosa         Closed   3/3/2018 12:22     system
# 20            Carlo Pasaol         Closed  2/14/2018 15:28     system
# 21        Sesenado Ordonez         Closed   3/5/2018 10:23     system
# 22         Rodolfo Villosa         Closed  2/17/2018 13:41     system
# 23         Christian Palma         Closed   2/17/2018 6:15     system
# 24    Arnold Ray Laguilles         Closed  2/15/2018 19:11    AG84437
# 25       Angeli Panganiban         Closed   2/16/2018 8:04     system
# 26    Arnold Ray Laguilles         Closed  2/13/2018 18:56    LS64896
# 27       Liberty Anne Sayo         Closed  2/20/2018 21:42     system
# 28    Arnold Ray Laguilles         Closed  2/22/2018 22:31     system
# 29    Arnold Ray Laguilles         Closed   3/4/2018 17:20     system
# ..                     ...            ...              ...        ...
# 244      Angeli Panganiban         Closed  3/24/2018 23:02     system
# 245        Rodolfo Villosa         Closed   3/25/2018 7:18     system
# 246  Concepcion Prosperoso         Closed   3/26/2018 3:09     system
# 247      Angeli Panganiban         Closed  3/28/2018 12:27    CP75703
# 248       Sesenado Ordonez         Closed  4/16/2018 20:06     system
# 249        Christian Palma         Closed  3/27/2018 18:07     system
# 250           Carlo Pasaol         Closed  3/28/2018 10:18     system
# 251  Concepcion Prosperoso         Closed  3/30/2018 16:18     system
# 252  Concepcion Prosperoso         Closed   4/6/2018 11:05     system
# 253        Rodolfo Villosa         Closed   3/30/2018 9:16     system
# 254  Christian Angel Reyes         Closed  3/26/2018 12:42    CR86441
# 255  Christian Angel Reyes         Closed  3/26/2018 12:42    CR86441
# 256  Christian Angel Reyes         Closed  3/29/2018 13:12     system
# 257      Angeli Panganiban         Closed  3/26/2018 21:04    AP96306
# 258      Liberty Anne Sayo         Closed   3/31/2018 6:03     system
# 259           Carlo Pasaol         Closed   4/2/2018 11:10     system
# 260           Carlo Pasaol         Closed  3/29/2018 12:11    CP75703
# 261      Liberty Anne Sayo         Closed  3/27/2018 13:45    LS64896
# 262           Carlo Pasaol         Closed    4/4/2018 9:04     system
# 263        Rodolfo Villosa         Closed   3/28/2018 4:16    RV75698
# 264        Rodolfo Villosa         Closed   3/28/2018 4:58    RV75698
# 265           Carlo Pasaol         Closed  3/31/2018 11:04     system
# 266  Concepcion Prosperoso         Closed   8/6/2018 15:04    UC59675
# 267  Concepcion Prosperoso         Closed  3/31/2018 20:00     system
# 268  Concepcion Prosperoso         Closed   4/1/2018 18:19     system
# 269  Concepcion Prosperoso         Closed   4/1/2018 22:01     system
# 270  Concepcion Prosperoso         Closed    4/5/2018 9:33     system
# 271  Concepcion Prosperoso         Closed    4/4/2018 9:21     system
# 272           Carlo Pasaol         Closed  3/30/2018 13:27    CP75703
# 273            Daryl Rojas         Closed  4/13/2018 10:03     system
#
#          Priority           Closed            Resolved by         Resolved  \
# 0      3 - Medium    1/8/2018 6:56                    NaN    1/8/2018 6:56
# 1         4 - Low   1/7/2018 14:07                    NaN   1/7/2018 14:07
# 2        2 - High  1/11/2018 16:11      Angeli Panganiban   1/8/2018 15:13
# 3         4 - Low  1/11/2018 16:13  Jesse Alueta Jadraque   1/8/2018 15:23
# 4        2 - High   3/6/2018 15:30                    NaN   3/6/2018 15:30
# 5      3 - Medium  1/13/2018 23:07        Rodolfo Villosa  1/10/2018 22:17
# 6        2 - High    2/2/2018 8:29           Carlo Pasaol   1/30/2018 5:49
# 7    1 - Critical  1/17/2018 23:14           Carlo Pasaol  1/14/2018 22:52
# 8        2 - High   2/18/2018 9:16       Sesenado Ordonez   2/15/2018 8:45
# 9      3 - Medium  1/20/2018 23:22           Carlo Pasaol  1/17/2018 22:54
# 10        4 - Low  1/24/2018 10:26                    NaN  1/24/2018 10:26
# 11     3 - Medium   1/24/2018 2:03           Carlo Pasaol   1/21/2018 1:21
# 12     3 - Medium   1/25/2018 8:14      Angeli Panganiban   1/22/2018 7:27
# 13        4 - Low   2/2/2018 10:36  Jesse Alueta Jadraque   2/2/2018 10:36
# 14     3 - Medium   2/2/2018 22:15        Rodolfo Villosa  1/30/2018 21:18
# 15       2 - High  3/22/2018 18:27      Liberty Anne Sayo  3/19/2018 14:33
# 16     3 - Medium  2/13/2018 12:20                    NaN  2/13/2018 12:20
# 17        4 - Low  2/21/2018 18:18                    NaN  2/21/2018 18:18
# 18       2 - High   2/7/2018 12:18        Rodolfo Villosa   2/4/2018 11:58
# 19       2 - High   3/3/2018 12:22        Rodolfo Villosa  2/28/2018 12:08
# 20     3 - Medium  2/14/2018 15:28                    NaN  2/14/2018 15:28
# 21       2 - High   3/5/2018 10:23       Sesenado Ordonez   3/2/2018 10:04
# 22     3 - Medium  2/17/2018 13:41                    NaN  2/17/2018 13:41
# 23       2 - High   2/17/2018 6:15                    NaN   2/17/2018 6:15
# 24     3 - Medium  2/15/2018 19:11             Arpit Giri  2/15/2018 19:11
# 25       2 - High   2/16/2018 8:04      Angeli Panganiban   2/13/2018 7:25
# 26     3 - Medium  2/13/2018 18:56      Liberty Anne Sayo  2/13/2018 18:56
# 27     3 - Medium  2/20/2018 21:42                    NaN  2/20/2018 21:42
# 28       2 - High  2/22/2018 22:31   Arnold Ray Laguilles  2/19/2018 21:40
# 29        4 - Low   3/4/2018 17:20      Liberty Anne Sayo   3/1/2018 16:47
# ..            ...              ...                    ...              ...
# 244    3 - Medium  3/24/2018 23:02      Angeli Panganiban  3/21/2018 22:09
# 245      2 - High   3/25/2018 7:18        Rodolfo Villosa   3/22/2018 6:44
# 246      2 - High   3/26/2018 3:09       Sesenado Ordonez   3/23/2018 2:15
# 247       4 - Low  3/28/2018 12:27           Carlo Pasaol  3/28/2018 12:27
# 248      2 - High  4/16/2018 20:06        Rodolfo Villosa  4/13/2018 18:19
# 249       4 - Low  3/27/2018 18:07        Christian Palma  3/24/2018 17:09
# 250      2 - High  3/28/2018 10:18           Carlo Pasaol   3/25/2018 9:47
# 251      2 - High  3/30/2018 16:18  Concepcion Prosperoso  3/27/2018 15:28
# 252       4 - Low   4/6/2018 11:05  Concepcion Prosperoso   4/3/2018 10:18
# 253      2 - High   3/30/2018 9:16        Rodolfo Villosa   3/27/2018 8:32
# 254      2 - High  3/26/2018 12:42  Christian Angel Reyes  3/26/2018 12:42
# 255    3 - Medium  3/26/2018 12:42  Christian Angel Reyes  3/26/2018 12:42
# 256      2 - High  3/29/2018 13:12  Christian Angel Reyes  3/26/2018 12:36
# 257       4 - Low  3/26/2018 21:04      Angeli Panganiban  3/26/2018 21:04
# 258      2 - High   3/31/2018 6:03        Rodolfo Villosa   3/28/2018 5:23
# 259    3 - Medium   4/2/2018 11:10           Carlo Pasaol  3/30/2018 10:48
# 260      2 - High  3/29/2018 12:11           Carlo Pasaol  3/29/2018 12:11
# 261    3 - Medium  3/27/2018 13:45      Liberty Anne Sayo  3/27/2018 13:45
# 262      2 - High    4/4/2018 9:04                    NaN    4/4/2018 9:04
# 263    3 - Medium   3/28/2018 4:16        Rodolfo Villosa   3/28/2018 4:16
# 264      2 - High   3/28/2018 4:58        Rodolfo Villosa   3/28/2018 4:58
# 265      2 - High  3/31/2018 11:04           Carlo Pasaol  3/28/2018 10:33
# 266      2 - High  3/31/2018 19:24  Concepcion Prosperoso  3/28/2018 19:05
# 267       4 - Low  3/31/2018 20:00  Concepcion Prosperoso  3/28/2018 19:11
# 268    3 - Medium   4/1/2018 18:19  Concepcion Prosperoso  3/29/2018 17:27
# 269      2 - High   4/1/2018 22:01  Concepcion Prosperoso  3/29/2018 21:05
# 270    3 - Medium    4/5/2018 9:33  Concepcion Prosperoso    4/2/2018 8:25
# 271      2 - High    4/4/2018 9:21      Angeli Panganiban    4/1/2018 8:34
# 272    3 - Medium  3/30/2018 13:27           Carlo Pasaol  3/30/2018 13:27
# 273      2 - High  4/13/2018 10:03       Benjamin Mendoza   4/10/2018 9:08
#
#                                            Description  \
# 0    Hi ITRS Team\r\r\r\n\r\r\r\nThe Publication Mo...
# 1    Hi Team,\r\r\r\n\r\r\r\nWhen I login to ITRS, ...
# 2    Hi ITRS Team,\r\r\r\n\r\r\r\nCould you please ...
# 3    Hi Team,\r\r\r\n\r\r\r\nPlease check the follo...
# 4    Hi ITRS team,\r\r\r\n\r\r\r\nWe have just conn...
# 5    Hi Team  , \r\r\r\n\r\r\r\nWe could see  below...
# 6    I'm part of "ICG EM 1T CTS-TTS-CASH CLEARING P...
# 7    Could you please enable the  below gateways.\r...
# 8    Hi ITRS Support,\r\r\r\n\r\r\r\nCan you please...
# 9    HI ITRS team,\r\r\r\n\r\r\r\nAs per below emai...
# 10   Hi ITRS Team,\r\r\r\n\r\r\r\nBelow sampler say...
# 11   Could you please Disable the below gateways.\r...
# 12   Hi Team,\r\r\r\n\r\r\r\nKindly advise us for b...
# 13   icgrecon02-vip1-ops : Critical : AUTOSYS : BAT...
# 14   Hi ITRS Team \r\r\r\n\r\r\r\nÃÂ \r\r\r\n\r\r\...
# 15   We have raised CMP#WS54183018 to get access fo...
# 16   Hi ITRS Support,\r\r\r\n\r\r\r\nCould I get so...
# 17   Hi ITRS team,\r\r\r\n\r\r\r\nThis is regarding...
# 18   Hi  Team,\r\r\r\n\r\r\r\nCould you please chec...
# 19   Hi ITRS Team,\r\r\r\nI am not able to run a si...
# 20   Konev, Vladimir [ICG-IT] <vk51086@imceu.eu.ssm...
# 21   Hi ITRS Team,\r\r\r\n\r\r\r\n  As per the belo...
# 22   Hi Team,\r\r\r\n\r\r\r\nKindly advise us for b...
# 23   Hi ITRS team,\r\r\r\n\r\r\r\nWe could see samp...
# 24   Hi Team ,\r\r\r\n\r\r\r\nWe could see Script f...
# 25   Hi ITRS Team,\r\r\r\n\r\r\r\nWe are getting at...
# 26   Hi Team\r\r\r\n\r\r\r\nPlease assist to provid...
# 27   I have ran the sync on TTS_FLEXCUBE_EMEA_PROD ...
# 28   eqitrs2c : Critical : ITM6 : LZIOS_BP_MEMLowSw...
# 29   Hi ITRS Team,\r\r\r\n\r\r\r\nAll the gateways ...
# ..                                                 ...
# 244  Hi Team,\r\r\r\n\r\r\r\nWe could see below scr...
# 245  eqitrs2c : Critical : ITM6 : LZIOS_BP_NetMEMUS...
# 246  rdcistitvld02p : Critical : ITM6 : LZIOS_BP_Ne...
# 247  ITRS Team,\r\r\r\nWe have created new dedicate...
# 248  Dear Team,\r\r\r\n\r\r\r\nCan you please check...
# 249  ITRS Team,\r\r\r\n\r\r\r\nPlease advise the pr...
# 250   Gateway: GPDW - icgemsmw02p v2\r\r\r\n Entity...
# 251  rdcistitvld02p : Critical : ITM6 : LZIOS_BP_Ne...
# 252  swdctinasf7005a : Critical : SANFILER : Volume...
# 253  rdcistitvld02p : Critical : ITM6 : LZIOS_BP_Ne...
# 254  rdcistitvld02p : Critical : ITM6 : LZIOS_BP_ME...
# 255  rdcistitvld02p : Critical : ITM6 : LZIOS_BP_ME...
# 256  rdcistitvld02p : Critical : ITM6 : LZIOS_BP_ME...
# 257  Hi Team,\r\r\r\n\r\r\r\nKindly provide access ...
# 258  Please can you help in provide me the write ac...
# 259  We had outage yesterday because of disk space ...
# 260  For Gateway  : GATEWAY : TTS_TIBCO_NAM_PROD   ...
# 261  Hi MS-team,\r\r\r\nCan you pls provide ps05412...
# 262        Script completed with errors. See log file.
# 263  Please provide access to ITRS Gateway: icg_eme...
# 264  Need to create a web dashboard for the attache...
# 265  Gateway: cmot_refer_global_ww_prod\r\r\r\nEnti...
# 266  ITRS WEB dashboard is not refresing . Please c...
# 267  Restart web server of http://hdcicgitvld04c:94...
# 268  Hi Team,\r\r\r\n\r\r\r\nI have upload below on...
# 269  Hi ITRS Team, \r\r\r\n\r\r\r\nBelow URL is not...
# 270  Dear ITRS Support Team,\r\r\r\n\r\r\r\nLast we...
# 271  eqitrs2c : Critical : ITM6 : LZIOS_BP_NetMEMUS...
# 272  Please revoke write access on below gateways f...
# 273  Full title: lrdicgitrap1p : Filesystem /var fr...
#
#                                  title_and_description  \
# 0    ('Pubmonitor can not be show in ITRS web page'...
# 1    ('ITRS access issue', "Hi Team,\r\r\n\r\r\nWhe...
# 2    ('RE: Sampling status failed.  || INC004921722...
# 3    ('Sampling status alert on Hardware - myeqtm1c...
# 4    ('[PENDING CONFIRMATION] Gateway - Service now...
# 5    (' RE: Script failure alert on  EPS access out...
# 6    ('ITRS is not working | TTS_GPRCT_EMEA_TECH_EM...
# 7    ('Please enable the gateways | MultipleGateway...
# 8    ('diskProfile Alert -| fxlmderiv_glbl_ww_prod|...
# 9    ('McShield (anti-virus Ã\x96"mcshield.exe") w...
# 10   ('FID expiry alert | TTS_LMS_NAM_PROD | SQL To...
# 11   ('Please Disable the gateways | MultipleGatewa...
# 12   ('Alerts in EMS | platems2_nam_us_prod | E4JMS...
# 13   ('153106 : icgrecon02-vip1-ops : BATCH INST PA...
# 14   ('FAIL [Script returned no output] error - ITR...
# 15   ('User Query | MSST_RPA_NAM_PROD | FKM | L2', ...
# 16   ('FKM Instance Count Rule', 'Hi ITRS Support,\...
# 17   (' ITRS missed Alerting', 'Hi ITRS team,\r\r\n...
# 18   ('Fail - ct_connect(): network packet layer: i...
# 19   ('ITRS Log file for the script error | fxlmbo_...
# 20   ("[PENDING CONFIRMATION] Can't accept errors |...
# 21   ('Kindly advise on Unsnooze logic on filesyste...
# 22   ('Alerts in EMS', "Hi Team,\r\r\n\r\r\nKindly ...
# 23   ('****Sampler script not found wxception****',...
# 24   (' Script failure alert on  RV Ticks All Risk ...
# 25   ('Reason: Missing JAR file: java.util.concurre...
# 26   ('TTS_GPRCT_APAC1_PROD SN Group Mapping', 'Hi ...
# 27   ('config access has not been granted|TTS|Confi...
# 28   ('eqitrs2c : Total System Swap free percentage...
# 29   ('All the gateways configured are getting gray...
# ..                                                 ...
# 244  ('Multiple script failures in EMEA CASH | cobr...
# 245  ('eqitrs2c : Net Memory Used high Last 15 mins...
# 246  ('rdcistitvld02p : Net Memory Used high Last 1...
# 247  ('RE: CITI FPP - ITRS & Service Now Group | TT...
# 248  ('Snooze option disabled for all our L1 and L2...
# 249  ('Gateway access', 'ITRS Team,\r\r\n\r\r\nPlea...
# 250  ('Sampling Status Fail | cmot_otms_nam_us_prod...
# 251  ('rdcistitvld02p : Net Memory Used high Last 1...
# 252  ('swdctinasf7005a : Volume /vol/swdcerv0006 is...
# 253  ('rdcistitvld02p : Net Memory Used high Last 1...
# 254  ('rdcistitvld02p : Total System Swap free perc...
# 255  ('rdcistitvld02p : Total System Swap free perc...
# 256  ('rdcistitvld02p : Total System Swap free perc...
# 257  ('ITRS access to accept alerts', 'Hi Team,\r\r...
# 258  ('Provide Write Access to ITRS Gateway | Equit...
# 259  ('ITRS Monitoring - mounts | moff_apac_hk_prod...
# 260  ('ITRS GATEWAY ACCESS | TTS_TIBCO_NAM_PROD | A...
# 261  ('FW: Prod ITRS Regional Initiative - Read-onl...
# 262  ('CitiFT Sampling status error for all three r...
# 263  ('ITRS Access | icg_emea_bigdata_gds_uk_prod |...
# 264  ('ITRS Web Dashboard', "Need to create a web d...
# 265  (' Sampling Status Fail | cmot_refer_global_ww...
# 266  ('ITRS Web dashboard not refreshing | Multiple...
# 267  ('Restart web server of http://hdcicgitvld04c:...
# 268  ('ITRS Dashboard', 'Hi Team,\r\r\n\r\r\nI have...
# 269  ('Web URL is not working ', 'Hi ITRS Team, \r\...
# 270  ('Snooze access for below MANAGED ENTITY NAME ...
# 271  ('eqitrs2c : Net Memory Used high Last 15 mins...
# 272  ('gateways access | Equities | Access | L2', '...
# 273  ('lrdicgitrap1p : Filesystem /var free space i...
#
#                                Prediction  \
# 0            Visualisation - WebDashboard
# 1                Gateway - Authentication
# 2              Netprobe - Troubleshooting
# 3                       Plugin - Database
# 4                Gateway - Authentication
# 5                Gateway - Authentication
# 6                Gateway - Authentication
# 7                      Gateway - Commands
# 8                 Plugin - System Windows
# 9                Plugin - File Monitoring
# 10                       License - Expiry
# 11                     Gateway - Commands
# 12               Gateway - Authentication
# 13   Plugin - API and Development Toolkit
# 14               Gateway - Authentication
# 15               Gateway - Authentication
# 16               Plugin - File Monitoring
# 17               Plugin - File Monitoring
# 18               Gateway - Authentication
# 19               Plugin - File Monitoring
# 20               Gateway - Authentication
# 21               Plugin - File Monitoring
# 22               Gateway - Authentication
# 23   Plugin - API and Development Toolkit
# 24   Plugin - API and Development Toolkit
# 25             Gateway - Managed Entities
# 26               Gateway - Authentication
# 27               Gateway - Authentication
# 28               Plugin - System Hardware
# 29           Visualisation - WebDashboard
# ..                                    ...
# 244  Plugin - API and Development Toolkit
# 245                Bespoke - Health Check
# 246                Bespoke - Health Check
# 247              Gateway - Authentication
# 248                    Gateway - Commands
# 249              Gateway - Authentication
# 250                   Plugin - Middleware
# 251                Bespoke - Health Check
# 252                Bespoke - Health Check
# 253                Bespoke - Health Check
# 254                Bespoke - Health Check
# 255                Bespoke - Health Check
# 256                Bespoke - Health Check
# 257              Gateway - Authentication
# 258              Gateway - Authentication
# 259              Plugin - System Hardware
# 260              Gateway - Authentication
# 261              Gateway - Authentication
# 262  Plugin - API and Development Toolkit
# 263              Gateway - Authentication
# 264          Visualisation - WebDashboard
# 265  Plugin - API and Development Toolkit
# 266          Visualisation - WebDashboard
# 267          Visualisation - WebDashboard
# 268          Visualisation - WebDashboard
# 269          Visualisation - WebDashboard
# 270                    Gateway - Commands
# 271                Bespoke - Health Check
# 272              Gateway - Authentication
# 273                Bespoke - Health Check
#
#                                           Expected  \
# 0                          Plugin - Web Monitoring
# 1                 Visualisation - Active Console 2
# 2                              Plugin - Middleware
# 3                                  Plugin - System
# 4                           Bespoke - Gateway Sync
# 5             Plugin - API and Development Toolkit
# 6                           Bespoke - Gateway Sync
# 7                                 Gateway - Others
# 8                         Plugin - System Hardware
# 9                                  Plugin - System
# 10                               Plugin - Database
# 11                                Gateway - Others
# 12                             Plugin - Middleware
# 13                               Plugin - Database
# 14            Plugin - API and Development Toolkit
# 15                        Plugin - File Monitoring
# 16             Gateway - Rules, Actions and alerts
# 17             Gateway - Rules, Actions and alerts
# 18                               Plugin - Database
# 19            Plugin - API and Development Toolkit
# 20                              Gateway - Commands
# 21                              Gateway - Commands
# 22                             Plugin - Middleware
# 23                             Plugin - Middleware
# 24                             Plugin - Middleware
# 25                             Plugin - Middleware
# 26                          Bespoke - Gateway Sync
# 27                          Bespoke - Gateway Sync
# 28                          Bespoke - Health Check
# 29   Gateway - Data Quality and Performance Tuning
# ..                                             ...
# 244           Plugin - API and Development Toolkit
# 245                         Bespoke - Health Check
# 246                         Bespoke - Health Check
# 247                       Gateway - Authentication
# 248                             Gateway - Commands
# 249                       Gateway - Authentication
# 250                            Plugin - Middleware
# 251                         Bespoke - Health Check
# 252                         Bespoke - Health Check
# 253                         Bespoke - Health Check
# 254                         Bespoke - Health Check
# 255                         Bespoke - Health Check
# 256                         Bespoke - Health Check
# 257                       Gateway - Authentication
# 258                       Gateway - Authentication
# 259                       Plugin - System Hardware
# 260                       Gateway - Authentication
# 261                       Gateway - Authentication
# 262           Plugin - API and Development Toolkit
# 263                       Gateway - Authentication
# 264                   Visualisation - WebDashboard
# 265           Plugin - API and Development Toolkit
# 266                   Visualisation - WebDashboard
# 267                   Visualisation - WebDashboard
# 268                   Visualisation - WebDashboard
# 269                   Visualisation - WebDashboard
# 270                             Gateway - Commands
# 271                         Bespoke - Health Check
# 272                       Gateway - Authentication
# 273                         Bespoke - Health Check
#
#                                          Predicted
# 0                     Visualisation - WebDashboard
# 1                         Gateway - Authentication
# 2                              Plugin - Middleware
# 3                                Plugin - Database
# 4    Gateway - Data Quality and Performance Tuning
# 5             Plugin - API and Development Toolkit
# 6                         Gateway - Authentication
# 7                               Gateway - Commands
# 8                          Plugin - System Windows
# 9              Gateway - Rules, Actions and Alerts
# 10                               Plugin - Database
# 11   Gateway - Data Quality and Performance Tuning
# 12             Gateway - Rules, Actions and Alerts
# 13                               Plugin - Database
# 14                                Gateway - Others
# 15                        Plugin - File Monitoring
# 16                        Plugin - File Monitoring
# 17                        Plugin - File Monitoring
# 18                             Plugin - Middleware
# 19                        Plugin - File Monitoring
# 20                        Gateway - Authentication
# 21                        Plugin - File Monitoring
# 22             Gateway - Rules, Actions and Alerts
# 23                               Gateway - Sharing
# 24            Plugin - API and Development Toolkit
# 25                        Plugin - File Monitoring
# 26                        Gateway - Authentication
# 27                        Gateway - Authentication
# 28                        Plugin - File Monitoring
# 29                    Visualisation - WebDashboard
# ..                                             ...
# 244           Plugin - API and Development Toolkit
# 245           Plugin - API and Development Toolkit
# 246           Plugin - API and Development Toolkit
# 247                       Gateway - Authentication
# 248                             Gateway - Commands
# 249                       Gateway - Authentication
# 250                            Plugin - Middleware
# 251                         Bespoke - Health Check
# 252                         Bespoke - Health Check
# 253           Plugin - API and Development Toolkit
# 254                         Bespoke - Health Check
# 255                         Bespoke - Health Check
# 256                         Bespoke - Health Check
# 257                       Gateway - Authentication
# 258                       Gateway - Authentication
# 259                              Plugin - Database
# 260                       Gateway - Authentication
# 261                       Gateway - Authentication
# 262           Plugin - API and Development Toolkit
# 263                       Gateway - Authentication
# 264                   Visualisation - WebDashboard
# 265           Plugin - API and Development Toolkit
# 266                   Visualisation - WebDashboard
# 267                   Visualisation - WebDashboard
# 268                   Visualisation - WebDashboard
# 269                   Visualisation - WebDashboard
# 270                             Gateway - Commands
# 271           Plugin - API and Development Toolkit
# 272                       Gateway - Authentication
# 273                         Bespoke - Health Check
#
# [274 rows x 17 columns]

# %%
ts['compare'] = ts['Predicted'] == ts['Expected']

# %%
ts['compare'].value_counts(normalize=True)*100
# Out:
# True     65.328467
# False    34.671533
# Name: compare, dtype: float64

# %%
ts.to_csv('lezze.csv')

# %%
ts['compare2'] = ts['Prediction'] == ts['Expected']

# %%
ts['compare2'].value_counts(normalize=True)*100
# Out:
# True     77.737226
# False    22.262774
# Name: compare2, dtype: float64
